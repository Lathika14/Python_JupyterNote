# %% [markdown]
# ## Pandas

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
# print(pd.__version__)

pip show pandas
# Out:
#   Cell In[8], line 3
#     pip show pandas
#         ^
# SyntaxError: invalid syntax

# %%
d = pd.Series([10,20,30,40,50])
print(d)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
print(data.loc[1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
data = pd.Series([10,20,30,40,50],index=["tamil","english","math","s","ss"])
print(data)
# Out:
# tamil      10
# english    20
# math       30
# s          40
# ss         50
# dtype: int64

# %%
 d =data.loc["tamil"]

# %%
print(d)
# Out:
# 10

# %%
print(data.loc["s"])
# Out:
# 40

# %%
print(data.iloc[1])
# Out:
# 20

# %%
print(data["tamil"])
# Out:
# 10

# %%
data["m"]=22

# %%
print(data)
# Out:
# tamil      10
# english    20
# math       30
# s          40
# ss         50
# m          22
# dtype: int64

# %%
students = {
    "name" : ["lathika","sridher","lingesh"],
    "age":[23,24,25],
    "subject":["DA","genai","DE"]
}

# %%
print(students)
# Out:
# {'name': ['lathika', 'sridher', 'lingesh'], 'age': [23, 24, 25], 'subject': ['DA', 'genai', 'DE']}

# %%
data = pd.DataFrame(students)

# %%
print(data)
# Out:
#       name  age subject
# 0  lathika   23      DA
# 1  sridher   24   genai
# 2  lingesh   25      DE

# %%
print(data.loc[0])
# Out:
# name       lathika
# age             23
# subject         DA
# Name: 0, dtype: object

# %%
students = pd.DataFrame([{"name":"bala","age":20,"subject":"DS"}],index=[3])

# %%
print(data)
# Out:
#    name  age subject
# 3  bala   20      DS

# %%
d=pd.DataFrame(students)

# %%
print(d)
# Out:
#    name  age subject
# 3  bala   20      DS

# %%
df = pd.concat([data,d])

# %%
print(df)
# Out:
#       name  age subject
# 0  lathika   23      DA
# 1  sridher   24   genai
# 2  lingesh   25      DE
# 3     bala   20      DS

# %%
 d=df.loc[(df["age"]<25) | (df["age"]>22)]

# %%
 d=df.loc[ ~ (df["age"]<25).str.]

# %%
print(d)
# Out:
#       name  age subject
# 2  lingesh   25      DE

# %%
df["name"].str.endswith("a")
# Out:
# 0     True
# 1    False
# 2    False
# 3     True
# Name: name, dtype: bool

# %%
read = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Documents\\CourseNotes\\Data.csv")

# %%
print(read)
# Out:
#     id    name  age department  salary
# 0  101    Ravi   25         IT   35000
# 1  102  Anitha   28         HR   40000
# 2  103   Kumar   30    Finance   45000
# 3  104   Divya   26         IT   38000

# %%
read_excel = pd.read_excel('C:\\Users\\Admin\\OneDrive\\Documents\\CourseNotes\\DA\\Excel_\\Excel_Data_Cleaning_Practice_500_Rows.xlsx')
print(read_excel)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 read_excel = pd.read_excel('C:\\Users\\Admin\\OneDrive\\Documents\\CourseNotes\\DA\\Excel_\\Excel_Data_Cleaning_Practice_500_Rows.xlsx')
#       2 print(read_excel)
#
# File ~\Lib\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
# ...

# %%
read.head()
# Out:
#     id    name  age department  salary
# 0  101    Ravi   25         IT   35000
# 1  102  Anitha   28         HR   40000
# 2  103   Kumar   30    Finance   45000
# 3  104   Divya   26         IT   38000

# %%
read.head(2)
# Out:
#     id    name  age department  salary
# 0  101    Ravi   25         IT   35000
# 1  102  Anitha   28         HR   40000

# %%
read.tail(2)
# Out:
#     id   name  age department  salary
# 2  103  Kumar   30    Finance   45000
# 3  104  Divya   26         IT   38000

# %%
import pandas as pd

# %%
students = {
    "name" : ["lathika","sridher","lingesh"],
    "age":[23,24,25],
    "subject":["DA","genai","DE"]
}

# %%
df = pd.DataFrame(students)

# %%
df
# Out:
#       name  age subject
# 0  lathika   23      DA
# 1  sridher   24   genai
# 2  lingesh   25      DE

# %%
print(df[df["age"]>=30])
# Out:
# Empty DataFrame
# Columns: [name, age, subject]
# Index: []

# %%
df[~ df["age"]<=20]
# Out:
#       name  age subject
# 0  lathika   23      DA
# 1  sridher   24   genai
# 2  lingesh   25      DE

# %%
df[(df["age"]>=20) | (df["age"]<=23)]
# Out:
#       name  age subject
# 0  lathika   23      DA
# 1  sridher   24   genai
# 2  lingesh   25      DE

# %%
df[df["subject"].isin(["DA","DE"])]
# Out:
#       name  age subject
# 0  lathika   23      DA
# 2  lingesh   25      DE

# %%
df.sort_values("name")
# Out:
#       name  age subject
# 0  lathika   23      DA
# 2  lingesh   25      DE
# 1  sridher   24   genai

# %%
data=pd.read_csv("C:\\Users\\Admin\\OneDrive\\Documents\\CourseNotes\\employee_data_cleaning_practice_200_rows.csv")

# %%
data
# Out:
#     Employee_ID Employee_Name   Age  Gender         Department        City  \
# 0             1   Sneha Kumar  38.0  Female            finance   Bangalore
# 1             2   Arun Sharma  34.0       F            finance     Chennai
# 2             3    Anitha Rao  17.0    male         Operations     chennai
# 3             4  Sneha Sharma  45.0    Male          Marketing     Chennai
# 4             5     Sneha Das  26.0       F         Operations     Chennai
# ..          ...           ...   ...     ...                ...         ...
# 195         196     Kavya Rao  51.0    Male          Marketing       Delhi
# 196         197   Nisha Kumar  32.0       M   Human Resources      chennai
# 197         198     Arun Iyer   0.0     NaN   Human Resources         Pune
# 198         199  Suresh Reddy  28.0       M          Marketing  BANGALORE
# 199         200   Gokul Reddy  32.0  female            finance     chennai
#
# ...

# %%
print(data.to_string())
# Out:
#     Employee_ID    Employee_Name   Age  Gender         Department        City                         Email Employment_Type     Salary Joining_Date  Performance_Score  Attendance_Percentage
# 0             1      Sneha Kumar  38.0  Female            finance   Bangalore        sneha.kumar1@gmail.com       Part time      53000   03-07-2020                NaN                   75.0
# 1             2      Arun Sharma  34.0       F            finance     Chennai      arun.sharma2@company.com        contract      53000   01-09-2023                6.0                    NaN
# 2             3       Anitha Rao  17.0    male         Operations     chennai         anitha.rao3@gmail.com       Part-Time      58000   27-01-2018                4.0                  100.0
# 3             4     Sneha Sharma  45.0    Male          Marketing     Chennai       sneha.sharma4@yahoo.com        contract      33000   10-01-2022                0.0                   -5.0
# ...

# %%
data.head(10)
# Out:
#   Employee_ID  Employee_Name   Age  Gender         Department       City  \
# 0           1    Sneha Kumar  38.0  Female            finance  Bangalore
# 1           2    Arun Sharma  34.0       F            finance    Chennai
# 2           3     Anitha Rao  17.0    male         Operations    chennai
# 3           4   Sneha Sharma  45.0    Male          Marketing    Chennai
# 4           5      Sneha Das  26.0       F         Operations    Chennai
# 5           6    Anitha Iyer  26.0  female   Human Resources        Pune
# 6           7     Vijay Iyer  25.0       M              Sales   Hyderbad
# 7           8    Nisha Reddy  41.0    male                 it      Delhi
# 8           9      Vijay Rao  46.0       F            Finance       Pune
# 9          10  Suresh Joseph  48.0     NaN            Finance     Mumbai
#
#                        Email Employment_Type  Salary Joining_Date  \
# 0     sneha.kumar1@gmail.com       Part time   53000   03-07-2020
# ...

# %%
data.tail()
# Out:
#     Employee_ID Employee_Name   Age  Gender         Department        City  \
# 195         196     Kavya Rao  51.0    Male          Marketing       Delhi
# 196         197   Nisha Kumar  32.0       M   Human Resources      chennai
# 197         198     Arun Iyer   0.0     NaN   Human Resources         Pune
# 198         199  Suresh Reddy  28.0       M          Marketing  BANGALORE
# 199         200   Gokul Reddy  32.0  female            finance     chennai
#
#                            Email Employment_Type  Salary Joining_Date  \
# 195       kavya.rao196@yahoo.com             NaN  118000   27-03-2020
# 196     nisha.kumar197@gmail.com        contract   83000   22-12-2019
# 197       arun.iyer198@yahoo.com       Part-Time  113000   16-03-2019
# 198  suresh.reddy199@company.com       Full-Time   68000   28-10-2019
# 199     gokul.reddy200@yahoo.com       Full-Time  113000   01-03-2025
#
#      Performance_Score  Attendance_Percentage
# 195                2.0                   90.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee_ID            200 non-null    str
#  1   Employee_Name          200 non-null    str
#  2   Age                    182 non-null    float64
#  3   Gender                 177 non-null    str
#  4   Department             197 non-null    str
#  5   City                   200 non-null    str
#  6   Email                  200 non-null    str
#  7   Employment_Type        164 non-null    str
#  8   Salary                 193 non-null    str
#  9   Joining_Date           196 non-null    str
#  10  Performance_Score      180 non-null    float64
#  11  Attendance_Percentage  180 non-null    float64
# dtypes: float64(3), str(9)
# memory usage: 18.9 KB

# %%
data.sort_values(["Employee_Name","Age"])
# Out:
#     Employee_ID    Employee_Name   Age  Gender         Department        City  \
# 84           85   anitha sharma   50.0    male          Marketing  BANGALORE
# 186         187    gokul joseph   35.0   Male             Finance  BANGALORE
# 169         170    gokul sharma   29.0  female   Human Resources   BANGALORE
# 16           17        hari rao   28.0       F                 IT       Delhi
# 33           34     karthik das   29.0       F         Operations     Chennai
# ..          ...              ...   ...     ...                ...         ...
# 119         120      Vijay Patel  51.0  Female         Operations    Hyderbad
# 100         101      Vijay Patel  55.0    male            Finance        Pune
# 36           37        Vijay Rao  43.0   Male               Sales     Chennai
# 8             9        Vijay Rao  46.0       F            Finance        Pune
# 190         191      Vijay Reddy  38.0       F          Marketing        Pune
#
# ...

# %%
data.isnull().sum()
# Out:
# Employee_ID               0
# Employee_Name             0
# Age                      18
# Gender                   23
# Department                3
# City                      0
# Email                     0
# Employment_Type          36
# Salary                    7
# Joining_Date              4
# Performance_Score        20
# Attendance_Percentage    20
# dtype: int64

# %%
df = data.dropna()

# %%
df.isnull().sum()
# Out:
# Employee_ID              0
# Employee_Name            0
# Age                      0
# Gender                   0
# Department               0
# City                     0
# Email                    0
# Employment_Type          0
# Salary                   0
# Joining_Date             0
# Performance_Score        0
# Attendance_Percentage    0
# dtype: int64

# %%
d = data.dropna(subset=["Age","Gender"])

# %%
d.isnull().sum()
# Out:
# Employee_ID               0
# Employee_Name             0
# Age                       0
# Gender                    0
# Department                3
# City                      0
# Email                     0
# Employment_Type          28
# Salary                    5
# Joining_Date              3
# Performance_Score        18
# Attendance_Percentage    14
# dtype: int64

# %%
data.fillna(0)
# Out:
#     Employee_ID Employee_Name   Age  Gender         Department        City  \
# 0             1   Sneha Kumar  38.0  Female            finance   Bangalore
# 1             2   Arun Sharma  34.0       F            finance     Chennai
# 2             3    Anitha Rao  17.0    male         Operations     chennai
# 3             4  Sneha Sharma  45.0    Male          Marketing     Chennai
# 4             5     Sneha Das  26.0       F         Operations     Chennai
# ..          ...           ...   ...     ...                ...         ...
# 195         196     Kavya Rao  51.0    Male          Marketing       Delhi
# 196         197   Nisha Kumar  32.0       M   Human Resources      chennai
# 197         198     Arun Iyer   0.0       0   Human Resources         Pune
# 198         199  Suresh Reddy  28.0       M          Marketing  BANGALORE
# 199         200   Gokul Reddy  32.0  female            finance     chennai
#
# ...

# %%
data = data["Gender"].fillna({"F":"Female"})

# %%
data
# Out:
# 0      Female
# 1           F
# 2        male
# 3        Male
# 4           F
#         ...
# 195      Male
# 196         M
# 197       NaN
# 198         M
# 199    female
# Name: Gender, Length: 200, dtype: str

# %%
data
# Out:
# 0      Female
# 1           F
# 2        male
# 3        Male
# 4           F
#         ...
# 195      Male
# 196         M
# 197       NaN
# 198         M
# 199    female
# Name: Gender, Length: 200, dtype: str

# %%
data
# Out:
#     Employee_ID Employee_Name   Age  Gender         Department        City  \
# 0             1   Sneha Kumar  38.0  Female            finance   Bangalore
# 1             2   Arun Sharma  34.0       F            finance     Chennai
# 2             3    Anitha Rao  17.0    male         Operations     chennai
# 3             4  Sneha Sharma  45.0    Male          Marketing     Chennai
# 4             5     Sneha Das  26.0       F         Operations     Chennai
# ..          ...           ...   ...     ...                ...         ...
# 195         196     Kavya Rao  51.0    Male          Marketing       Delhi
# 196         197   Nisha Kumar  32.0       M   Human Resources      chennai
# 197         198     Arun Iyer   0.0     NaN   Human Resources         Pune
# 198         199  Suresh Reddy  28.0       M          Marketing  BANGALORE
# 199         200   Gokul Reddy  32.0  female            finance     chennai
#
# ...

# %%
data["Gender"]=data["Gender"].fillna({"F":"Female","M":"Male"})

# %%
data
# Out:
#     Employee_ID Employee_Name   Age  Gender         Department        City  \
# 0             1   Sneha Kumar  38.0  Female            finance   Bangalore
# 1             2   Arun Sharma  34.0       F            finance     Chennai
# 2             3    Anitha Rao  17.0    male         Operations     chennai
# 3             4  Sneha Sharma  45.0    Male          Marketing     Chennai
# 4             5     Sneha Das  26.0       F         Operations     Chennai
# ..          ...           ...   ...     ...                ...         ...
# 195         196     Kavya Rao  51.0    Male          Marketing       Delhi
# 196         197   Nisha Kumar  32.0       M   Human Resources      chennai
# 197         198     Arun Iyer   0.0     NaN   Human Resources         Pune
# 198         199  Suresh Reddy  28.0       M          Marketing  BANGALORE
# 199         200   Gokul Reddy  32.0  female            finance     chennai
#
# ...

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 195    False
# 196    False
# 197    False
# 198    False
# 199    False
# Length: 200, dtype: bool

# %%
df
# Out:
#     Employee_ID Employee_Name   Age  Gender         Department        City  \
# 2             3    Anitha Rao  17.0    male         Operations     chennai
# 3             4  Sneha Sharma  45.0    Male          Marketing     Chennai
# 4             5     Sneha Das  26.0       F         Operations     Chennai
# 5             6   Anitha Iyer  26.0  female   Human Resources         Pune
# 7             8   Nisha Reddy  41.0    male                 it       Delhi
# ..          ...           ...   ...     ...                ...         ...
# 190         191   Vijay Reddy  38.0       F          Marketing        Pune
# 193         194   Suresh Nair  38.0       F              Sales     Chennai
# 194         195  Anitha Kumar  27.0       M                 HR  BANGALORE
# 196         197   Nisha Kumar  32.0       M   Human Resources      chennai
# 198         199  Suresh Reddy  28.0       M          Marketing  BANGALORE
#
# ...

# %%
df.duplicated()
# Out:
# 2      False
# 3      False
# 4      False
# 5      False
# 7      False
#        ...
# 190    False
# 193    False
# 194    False
# 196    False
# 198    False
# Length: 100, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee_ID            200 non-null    str
#  1   Employee_Name          200 non-null    str
#  2   Age                    182 non-null    float64
#  3   Gender                 177 non-null    str
#  4   Department             197 non-null    str
#  5   City                   200 non-null    str
#  6   Email                  200 non-null    str
#  7   Employment_Type        164 non-null    str
#  8   Salary                 193 non-null    str
#  9   Joining_Date           196 non-null    str
#  10  Performance_Score      180 non-null    float64
#  11  Attendance_Percentage  180 non-null    float64
# dtypes: float64(3), str(9)
# memory usage: 18.9 KB

# %%
import numpy as np
data["Employee_ID"]=data["Employee_ID"].astype(np.int64)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[84], line 2
#       1 import numpy as np
# ----> 2 data["Employee_ID"]=data["Employee_ID"].astype(np.int64)
#
# File ~\Lib\site-packages\pandas\core\generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537             results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6538
#    6539         else:
#    6540             # else, only a single dtype is given
# -> 6541             new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543             return res.__finalize__(self, method="astype")
#    6544
#
# File ~\Lib\site-packages\pandas\core\internals\managers.py:614, in BaseBlockManager.astype(self, dtype, errors)
#     613 def astype(self, dtype, errors: str = "raise") -> Self:
# ...

# %%
print(data.to_string())
# Out:
#     Employee_ID    Employee_Name   Age  Gender         Department        City                         Email Employment_Type     Salary Joining_Date  Performance_Score  Attendance_Percentage
# 0             1      Sneha Kumar  38.0  Female            finance   Bangalore        sneha.kumar1@gmail.com       Part time      53000   03-07-2020                NaN                   75.0
# 1             2      Arun Sharma  34.0       F            finance     Chennai      arun.sharma2@company.com        contract      53000   01-09-2023                6.0                    NaN
# 2             3       Anitha Rao  17.0    male         Operations     chennai         anitha.rao3@gmail.com       Part-Time      58000   27-01-2018                4.0                  100.0
# 3             4     Sneha Sharma  45.0    Male          Marketing     Chennai       sneha.sharma4@yahoo.com        contract      33000   10-01-2022                0.0                   -5.0
# ...

# %%
print(data.dtype())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 print(data.dtype())
#
# File ~\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee_ID            200 non-null    str
#  1   Employee_Name          200 non-null    str
#  2   Age                    182 non-null    float64
#  3   Gender                 177 non-null    str
#  4   Department             197 non-null    str
#  5   City                   200 non-null    str
#  6   Email                  200 non-null    str
#  7   Employment_Type        164 non-null    str
#  8   Salary                 193 non-null    str
#  9   Joining_Date           196 non-null    str
#  10  Performance_Score      180 non-null    float64
#  11  Attendance_Percentage  180 non-null    float64
# dtypes: float64(3), str(9)
# memory usage: 18.9 KB

# %%
data["City"].str.title()
# Out:
# 0       Bangalore
# 1         Chennai
# 2         Chennai
# 3         Chennai
# 4         Chennai
#           ...
# 195         Delhi
# 196       Chennai
# 197          Pune
# 198    Bangalore
# 199       Chennai
# Name: City, Length: 200, dtype: str

# %%
data["Gender"].str.replace("F","Female")
# Out:
# 0      Femaleemale
# 1           Female
# 2             male
# 3             Male
# 4           Female
#           ...
# 195           Male
# 196              M
# 197            NaN
# 198              M
# 199         female
# Name: Gender, Length: 200, dtype: str

# %%
data["Year"] = data["Joining_Date"].dt.year

# %%
data["Joining_Date"]=pd.to_datetime(data["Joining_Date"],format="mixed")

# %%
data["Year"]
# Out:
# 0      2020.0
# 1      2023.0
# 2      2018.0
# 3      2022.0
# 4      2021.0
#         ...
# 195    2020.0
# 196    2019.0
# 197    2019.0
# 198    2019.0
# 199    2025.0
# Name: Year, Length: 200, dtype: float64

# %%
data.columns
# Out:
# Index(['Employee_ID', 'Employee_Name', 'Age', 'Gender', 'Department', 'City',
#        'Email', 'Employment_Type', 'Salary', 'Joining_Date',
#        'Performance_Score', 'Attendance_Percentage', 'Year'],
#       dtype='str')

# %%
data["day_name"] =data["Joining_Date"].dt.day_name()

# %%
data
# Out:
#     Employee_ID Employee_Name   Age  Gender         Department        City  \
# 0             1   Sneha Kumar  38.0  Female            finance   Bangalore
# 1             2   Arun Sharma  34.0       F            finance     Chennai
# 2             3    Anitha Rao  17.0    male         Operations     chennai
# 3             4  Sneha Sharma  45.0    Male          Marketing     Chennai
# 4             5     Sneha Das  26.0       F         Operations     Chennai
# ..          ...           ...   ...     ...                ...         ...
# 195         196     Kavya Rao  51.0    Male          Marketing       Delhi
# 196         197   Nisha Kumar  32.0       M   Human Resources      chennai
# 197         198     Arun Iyer   0.0     NaN   Human Resources         Pune
# 198         199  Suresh Reddy  28.0       M          Marketing  BANGALORE
# 199         200   Gokul Reddy  32.0  female            finance     chennai
#
# ...

# %%
def categorize(age):
    return 'Senior' if age > 30 else 'Junior'
 
data['Category'] = data['Age'].apply(lambda a:"High" if a>40 else "Low")
# or with a lambda:
#df['Category'] = df['Age'].apply(lambda x: 'Senior' if x > 30 else 'Junior')

# %%
data
# Out:
#     Employee_ID Employee_Name   Age  Gender         Department        City  \
# 0             1   Sneha Kumar  38.0  Female            finance   Bangalore
# 1             2   Arun Sharma  34.0       F            finance     Chennai
# 2             3    Anitha Rao  17.0    male         Operations     chennai
# 3             4  Sneha Sharma  45.0    Male          Marketing     Chennai
# 4             5     Sneha Das  26.0       F         Operations     Chennai
# ..          ...           ...   ...     ...                ...         ...
# 195         196     Kavya Rao  51.0    Male          Marketing       Delhi
# 196         197   Nisha Kumar  32.0       M   Human Resources      chennai
# 197         198     Arun Iyer   0.0     NaN   Human Resources         Pune
# 198         199  Suresh Reddy  28.0       M          Marketing  BANGALORE
# 199         200   Gokul Reddy  32.0  female            finance     chennai
#
# ...
