# %% [markdown]
# ## String Methods

# %%
a="hello"
b="welcome"
print(a+b)
# Out:
# hellowelcome

# %%
print(a.capitalize())
# Out:
# Hello

# %%
text ="StrinG"
print(text.casefold())
# Out:
# string

# %%
print(text.center(30))
# Out:
#             StrinG

# %%
text1="madam"
print(text1.count("m"))
print(text1.endswith("a"))
# Out:
# 2
# False

# %%
g="the\tname"
print(g.expandtabs(9))
# Out:
# the      name

# %%
name="this is@is@lathika"
print(name.find("a"))
print(name.partition("@"))
print(name.replace("@"," "))
# Out:
# 12
# ('this is', '@', 'is@lathika')
# this is is lathika

# %%
print("I am {Name} , My age  is {Age}".format(Name = 'lathika' ,Age = 22))
# Out:
# I am lathika , My age  is 22

# %%
print("I am {4} , My age  is {1}".format("lathika",33))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 print("I am {4} , My age  is {1}".format("lathika",33))
#
# IndexError: Replacement index 4 out of range for positional args tuple

# %%
text="hello "
print(text.index(" "))
# Out:
# 5

# %%
num="dsd1323"
print(num.isalnum())
print(num.isalpha())
# Out:
# True
# False

# %%
print("".isascii())
# Out:
# False

# %%
print("9>0".isdigit())
# Out:
# False

# %%
print("for".isidentifier())
# Out:
# True

# %%
for="this is"
print(for)
# Out:
#   Cell In[71], line 1
#     for="this is"
#        ^
# SyntaxError: invalid syntax

# %%
f="fgsHBJBKJM"
print(f.lower())
# Out:
# fgshbjbkjm

# %%
r="Hello"
print(r.isnumeric())

print(r.isprintable())
print(r.isspace())
print(r.istitle())
print(r.isupper())
print(r.upper())
print(r.lower())
print(r.islower())
# Out:
# False
# True
# False
# True
# False
# HELLO
# hello
# False

# %%
list=["this","is","techpanda"]
print(" ".join(list))
# Out:
# this is techpanda

# %%
print("Hii".ljust(9,"i"))
# Out:
# Hiiiiiiii

# %%
print("    Hii".lstrip())
# Out:
# Hii

# %%
m={'a': '1', 'b': '2'}
print(str.maketrans(m))
# Out:
# {97: '1', 98: '2'}

# %%
print("a,b,c,d,e,f".split(","))
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
name ="     hello   "
print(name.rstrip())
# Out:
#      hello

# %%
n="line\nline"
print(n.splitlines())
print(n.startswith("l"))
print(n.swapcase())
# Out:
# ['line', 'line']
# True
# LINE
# LINE

# %%
v="the"
print(v.zfill(4))
# Out:
# 0the

# %%
import logging
logging.basicConfig(level=logging.ERROR)

logger = logging.getLogger(__name__)
try:
    a = 10
    b = 0
    result = a / b

except ZeroDivisionError:
    logger.exception("Cannot divide by zero")
# Out:
# ERROR:__main__:Cannot divide by zero
# Traceback (most recent call last):
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_5996\1494917672.py", line 8, in <module>
#     result = a / b
#              ~~^~~
# ZeroDivisionError: division by zero
