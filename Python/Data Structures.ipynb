# %% [markdown]
# ### Data Structures
#
# + List
#
# + Tuples
#
# + Set
#
# + Dictionary

# %% [markdown]
# ### List
#
# + []
# + Ordered
# + mutable
# +

# %%
list_name=["lathika",332,"age"]
type(list_name)
print(list_name)
# Out:
# ['lathika', 332, 'age']

# %%
list_name[1]
# Out:
# 332

# %%
a=list(range(3))
a

for i in range(4):
    print(i)

print(a)
# Out:
# 0
# 1
# 2
# 3
# [0, 1, 2]

# %%
h=["hi","hello"]*9
print(h)
# Out:
# ['hi', 'hello', 'hi', 'hello', 'hi', 'hello', 'hi', 'hello', 'hi', 'hello', 'hi', 'hello', 'hi', 'hello', 'hi', 'hello', 'hi', 'hello']

# %%
j=[[2]*2]*3
print(j)
# Out:
# [[2, 2], [2, 2], [2, 2]]

# %%
num =[1,2,3,455,22,4,3]
del num[2:5]
print(num)
# Out:
# [1, 2, 4, 3]

# %%
num[1:6:2]
# Out:
# [2, 455, 4]

# %%
num[-1]
# Out:
# 3

# %%
num[:-1]
# Out:
# [1, 2, 3, 455, 22, 4]

# %%
num.append("hello")
num
# Out:
# [1, 2, 4, 3, 'hello']

# %%
number=[10,20,30,40,50]
number.append(450)
number
# Out:
# [10, 20, 30, 40, 50, 450]

# %%
number.insert(3,"hello")
number
# Out:
# [10, 20, 30, 'hello', 40, 50, 450]

# %%
number.extend("w3213")
number
# Out:
# [10, 20, 30, 'hello', 40, 50, 450, 'w', '3', '2', '1', '3']

# %%
number.remove(10)
number
# Out:
# [20, 30, 'hello', 40, 50, 450, 'w', '3', '2', '1', '3']

# %%
number
# Out:
# [20, 30, 'hello', 40, 50, 450, 'w', '3', '2', '1', '3']

# %%
number.sort()
number
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 number.sort()
#       2 number
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
num=[1,3,2,55,5,3242,8976]
num.sort()
num
# Out:
# [1, 2, 3, 5, 55, 3242, 8976]

# %%
new_num=sorted(num)
new_num
# Out:
# [1, 2, 3, 5, 55, 3242, 8976]

# %%
nums = [5, 2, 9, 1]
nums.sort()                  # in-place, returns None
new_list = sorted(nums)      
new_list
# Out:
# [1, 2, 5, 9]

# %%
labels = ['even' if x % 2 == 0 else 'odd' for x in range(6)]
labels
# Out:
# ['even', 'odd', 'even', 'odd', 'even', 'odd']

# %%
for i in range(3):
    if i%2==0:
        print("even")
    else:
        print("odd")

# %%
import copy
num =[[1,2,3],[2,3,4]]
shallow=num.copy()

shallow[1][1]=111
print(num)

deep=copy.deepcopy(num)
deep[1][0]=23
print(deep)
print(num)
# Out:
# [[1, 2, 3], [2, 111, 4]]
# [[1, 2, 3], [23, 111, 4]]
# [[1, 2, 3], [2, 111, 4]]

# %%
nums.count(5)
list_num=[11,1,22,3,22,44]
list_num.count(22)
list_num.index(1)
list_num.pop(2)
list_num.pop(3)
list_num.reverse()
print(list_num)
# Out:
# [44, 3, 1, 11]

# %% [markdown]
# ### Tuple
#
# + 1 D
# + diff data types stored
# + immutable
# + ordered
# + allow duplicates

# %%
t=(1,2,3)
t
# Out:
# (1, 2, 3)

# %%
t1=(1,"hello","hii","hii",44,1,44)
t1
# Out:
# (1, 'hello', 'hii', 'hii', 44, 1, 44)

# %%
t2=(2,)
t2
# Out:
# (2,)

# %%
t=tuple("hello")
t
t1=([1,2,3])
print(t1.type())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 4
#       1 t=tuple("hello")
#       2 t
#       3 t1=([1,2,3])
# ----> 4 print(t1.type())
#
# AttributeError: 'list' object has no attribute 'type'

# %%
packed = (1,2)
packed
# Out:
# (1, 2)

# %%
x,y=packed
x
y
# Out:
# 2

# %%
a=10
b=20

# %%
a,b=b,a

a,b
# Out:
# (20, 10)

# %%
t1
# Out:
# (1, 'hello', 'hii', 'hii', 44, 1, 44)

# %%
t1[0]
# Out:
# 1

# %%
t1[3]
# Out:
# 'hii'

# %%
t1[1:6:2]
# Out:
# ('hello', 'hii', 1)

# %%
t1[1:6:2]
# Out:
# ('hello', 'hii', 1)

# %%
t1.count("hello")
# Out:
# 1

# %%
t1.index("hii")
# Out:
# 2

# %%
t1[0]
# Out:
# 1

# %%
t=(1,[2,3],3)
t(hash(t))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 2
#       1 t=(1,[2,3],3)
# ----> 2 t(hash(t))
#
# TypeError: unhashable type: 'list'

# %%
a,*b,c=(1,2,3,4,5,6,78)

print(a,b,c)
# Out:
# 1 [2, 3, 4, 5, 6] 78

# %%
from collections import namedtuple

# %%
# named_tuple = namedtuple("name",[x,y])
# names=name(1,2)
# names.x,names.y
# names[x]

Point = namedtuple('Point', ['x', 'y'])
p1 = Point(3, 4)
p1.x, p1.y        # 3, 4  - access by name
p1[0], p1[1]

p1._asdict()
# Out:
# {'x': 3, 'y': 4}

# %%
x=10
print(hash(x))
# Out:
# 10

# %%
name="lathika"
print(hash(name))
# Out:
# 2461496811159933642

# %%
ha=(1,"name")
print(hash(ha))

value={ha:"student"}

print(value)
# Out:
# -153148931311639795
# {(1, 'name'): 'student'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 8
#       4 value={ha:"student"}
#       5
#       6 print(value)
#       7
# ----> 8 print(value[1])
#
# KeyError: 1

# %% [markdown]
# ### Set
#
# + unordered

# %%
s=set()

# %%
type(s)
# Out:
# set

# %%
s={1,2,3,4,56,232,1,"Hii"}
type(s)
# Out:
# set

# %%
s
# Out:
# {1, 2, 232, 3, 4, 56, 'Hii'}

# %%
se={1,1,2,2,3,4,null}
se
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 se={1,1,2,2,3,4,null}
#       2 se
#
# NameError: name 'null' is not defined

# %%
se.add(56)
se
# Out:
# {56}

# %%
se.clear()
se
# Out:
# set()

# %%
se.remove(2)
se
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 se.remove(2)
#       2 se
#
# KeyError: 2

# %%
se.pop()
# Out:
# 56

# %%
se.pop()
se
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 se.pop()
#       2 se
#
# KeyError: 'pop from an empty set'

# %%
se
# Out:
# set()

# %%
s={1,2,3,4,5,563}
s
# Out:
# {1, 2, 3, 4, 5, 563}

# %%
s.pop()
s
# Out:
# {2, 3, 4, 5, 563}

# %%
s
# Out:
# {2, 3, 4, 5, 563}

# %%
s.pop()
# Out:
# 2

# %%
s
# Out:
# {3, 4, 5, 563}

# %%
d=s.copy()
d
# Out:
# {3, 4, 5, 563}

# %%
s.clear()
s
# Out:
# set()

# %%
d.difference

# %%
d
# Out:
# {3, 4, 5, 563}

# %%
a={1,2,3,4,5,6}
b={3,4,5,7,8,9}

a.union(b)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
a.intersection(b)
# Out:
# {3, 4, 5}

# %%
b.difference(a)
# Out:
# {7, 8, 9}

# %%
a.symmetric_difference(b)
# Out:
# {1, 2, 6, 7, 8, 9}

# %%
a.update(b)

# %%
a
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
b
# Out:
# {3, 4, 5, 7, 8, 9}

# %%
b.update(a)
b
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
a.issubset(b)
# Out:
# True

# %%
c={34,43,56,23,87}
d={11,22,33,44,55}

c.issubset(d)
# Out:
# False

# %%
a.pop()
a
# Out:
# {2, 3, 4, 5, 6, 7, 8, 9}

# %%
a.issubset(b)
# Out:
# True

# %%
a.issuperset(d)
# Out:
# False

# %%
h={1,2,3}
f={1,2,3,5}
f.issuperset(h)
# Out:
# True

# %%
h.isdisjoint(f)
# Out:
# False

# %% [markdown]
# ### dict

# %%
dic={"name" :"lathika","age":33}
dic
# Out:
# {'name': 'lathika', 'age': 33}

# %%
d=dict.fromkeys(["a","c","c"],2)
d
# Out:
# {'a': 2, 'c': 2}

# %%
d4 = dict([('a', 6), ('a', 2),('a',5)])
d4
# Out:
# {'a': 5}

# %%
d1=dict(zip(["a","v","e","p","o"],[1,2,3,4]))
d1
# Out:
# {'a': 1, 'v': 2, 'e': 3, 'p': 4}

# %%
d1["a"]
# Out:
# 1

# %%
d1["p"]
# Out:
# 4

# %%
d1.get("a")
# Out:
# 1

# %%
d1.items()
# Out:
# dict_items([('a', 1), ('v', 2), ('e', 3), ('p', 4)])

# %%
d1.keys()
# Out:
# dict_keys(['a', 'v', 'e', 'p'])

# %%
d1.pop("p")
# Out:
# 4

# %%
d1
# Out:
# {'a': 1, 'v': 2, 'e': 3}

# %%
d1.pop(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 d1.pop(2)
#
# KeyError: 2

# %%
d1.popitem()
# Out:
# ('e', 3)

# %%
d1
# Out:
# {'a': 1, 'v': 2}

# %%
d1.setdefault("a",11)
# Out:
# 23

# %%
d1
# Out:
# {'a': 23, 'v': 2}

# %%
d1.update({"g":55,"y":99})
d1
# Out:
# {'a': 23, 'v': 2, 'g': 55, 'y': 99}

# %%
d1.

# %%
data={
    "student1":{"Name":"Lathika","sub":["DA","DS","Genai"]},
    "student2":{"Name":"vinoth","sub":["DA","DS","Genai"]}
}

data
# Out:
# {'student1': {'Name': 'Lathika', 'sub': ['DA', 'DS', 'Genai']},
#  'student2': {'Name': 'vinoth', 'sub': ['DA', 'DS', 'Genai']}}

# %%
data["student1"]["sub"][0]
# Out:
# 'DA'

# %%
data["student1"][0:4]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 data["student1"][0:1]
#
# KeyError: slice(0, 1, None)

# %%
data["student1"]["sub"].append("Python")

# %%
data
# Out:
# {'student1': {'Name': 'Lathika', 'sub': ['DA', 'DS', 'Genai', 'Python']},
#  'student2': {'Name': 'vinoth', 'sub': ['DA', 'DS', 'Genai']}}

# %%
data["student1"]["Name"].append("Python")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 data["student1"]["Name"].append("Python")
#
# AttributeError: 'str' object has no attribute 'append'

# %%
data["age"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 data["age"]
#
# KeyError: 'age'

# %%
data.get("age",{"nothing"})
# Out:
# {'nothing'}

# %%
d={}
type(d)
# Out:
# dict

# %%
d["age"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 d["age"]
#
# KeyError: 'age'

# %%
d.setdefault("age",[]).append(33)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 d.setdefault("age",[]).append(33)
#
# AttributeError: 'NoneType' object has no attribute 'append'

# %%
d
# Out:
# {'age': None}

# %%
d
# Out:
# {'age': None}

# %%
d
# Out:
# {'age': None}

# %%
d.setdefault("name",[]).append("lathika")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 d.setdefault("name",[]).append("lathika")
#
# AttributeError: 'NoneType' object has no attribute 'append'

# %%
d
# Out:
# {'age': None, 'name': None}

# %%
a={}
a
# Out:
# {}

# %%
a.setdefault("name",[]).append("lathika")

# %%
a
# Out:
# {'name': ['lathika']}

# %%
a["name"].append("vimal")

# %%
a
# Out:
# {'name': ['lathika', 'vimal']}

# %%
d1 = {'a': 1, 'b': 2}
d2 = {'b': 3, 'c': 4}

# %%
merge={**d1,**d2}
merge
# Out:
# {'a': 1, 'b': 3, 'c': 4}

# %%
m=dict(d1,**d2)

# %%
m
# Out:
# {'a': 1, 'b': 3, 'c': 4}

# %%
mm=d1 | d2

# %%
mm
# Out:
# {'a': 1, 'b': 3, 'c': 4}

# %%
from collections import defaultdict

# %%
w=defaultdict(list)

for word in ["apple","banana","hii","python"]:
    w[word[1]].append(word)



w
# Out:
# defaultdict(list,
#             {'p': ['apple'], 'a': ['banana'], 'i': ['hii'], 'y': ['python']})

# %%
counter = defaultdict(int)
for ch in 'mississippi':
    counter[ch] += 1

counter
# Out:
# defaultdict(int, {'m': 1, 'i': 4, 's': 4, 'p': 2})
