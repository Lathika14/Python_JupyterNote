# %% [markdown]
# ## Data types

# %%
a =2000
type(a)
# Out:
# int

# %%
a= 2.3
type(a)
# Out:
# float

# %%
a =2883

# %%
print(a)
# Out:
# 2883

# %%
a = 'hii','dshba'
type(a)
# Out:
# tuple

# %%
a =(2,3,4,5,6,78,6,'hii','helo',True,3.566)

# %%
a
# Out:
# (2, 3, 4, 5, 6, 78, 6, 'hii', 'helo', True, 3.566)

# %%
type(a)
# Out:
# tuple

# %%
a={'name':'lathika','age':24}

# %%
a
# Out:
# {'name': 'lathika', 'age': 24}

# %%
type(a)
# Out:
# dict

# %%
set=(2,3,4)

# %%
a =range(2,4)

# %%
a
# Out:
# range(2, 4)

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
a=True

# %%
a
# Out:
# True

# %%
type(a)
# Out:
# bool

# %%
a = None

# %%
type(a)
# Out:
# NoneType

# %%
b =100
type(b)
# Out:
# int

# %%
c =str(b)

# %%
c
# Out:
# '100'

# %%
type(c)
# Out:
# str

# %%
a='100'

# %%
b=int(a)

# %%
c=b+10

# %%
print(c)
# Out:
# 110

# %% [markdown]
# ## Operators
#
# + Arithmetic Operators
# + Comparison (Relational) Operators\
# + Assignment Operators

# %%
print(1+3)
# Out:
# 4

# %%
2-6
# Out:
# -4

# %%
10-5
# Out:
# 5

# %%
2*2
# Out:
# 4

# %%
10*5
# Out:
# 50

# %%
13/2
# Out:
# 6.5

# %%
13//2
# Out:
# 6

# %%
5**5
# Out:
# 3125

# %%
5*2
# Out:
# 10

# %%
5%2
# Out:
# 1

# %%
10000000<1000
# Out:
# False

# %%
a=100
b=200

c=(a>90) and (b>100000)

c
# Out:
# False

# %%
c= not(a<=100)

# %%
c
# Out:
# False

# %%
a=10

# %%
a
# Out:
# 10

# %%
a = a+10
a
# Out:
# 20

# %%
a **=10 # a=a+10
a
# Out:
# 1024.0

# %%
a=10

  for i in range(10):
        print(i)
    i+=2
# Out:
#   File <string>:5
#     i+=2
#         ^
# IndentationError: unindent does not match any outer indentation level

# %%
a=5&4
a
# Out:
# 4

# %%
a=5|4
a
# Out:
# 5

# %%
a=5>>4
a
# Out:
# 0

# %%
a=['hii','hlo','hey']
b=[1,2,3,4]

# %%
a
# Out:
# ['hii', 'hlo', 'hey']

# %%
'ho' not in a
# Out:
# True

# %%
a is not b
# Out:
# True

# %%
    a
# Out:
# ['hii', 'hlo', 'hey']

# %%
a = -1

# %%
a
# Out:
# -1

# %%
peinr(+a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[144], line 1
# ----> 1 peinr(+a)
#
# NameError: name 'peinr' is not defined

# %%
print(-a)
# Out:
# 1

# %%
a =10
a
# Out:
# 10

# %%
a=input(int())
# Out:
# 0 232eqsdasx

# %%
a
# Out:
# '2423q'

# %%
a=input(int())
# Out:
# 0 dsaxz

# %%
a = int(input())
# Out:
#  dcsncsdknc
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[159], line 1
# ----> 1 a = int(input())
#
# ValueError: invalid literal for int() with base 10: 'dcsncsdknc'

# %%
a
# Out:
# 241324234

# %%
name = str(input('Enter the name : '))
# Out:
# Enter the name :  gcdhgcfh
