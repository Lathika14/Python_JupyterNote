# %% [markdown]
# ## Python Intro
#
# + history

# %%
print('hii')
# Out:
# hii

# %% [markdown]
# ## basic python

# %%
print(1+2)
# Out:
# 3

# %%
print(20-20)
# Out:
# 0

# %%
type()

# %%
print('heelo')
# Out:
# heelo

# %%
name = 'lathika'

# %%
print(name)
# Out:
# lathika

# %%
type(name)
# Out:
# str

# %%
age=23.4

# %%
print(age)
# Out:
# 23.4

# %%
type(age)
# Out:
# float
