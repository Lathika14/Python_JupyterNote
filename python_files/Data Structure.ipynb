# %% [markdown]
# ### Data Structure
#
# * List
# * Tuple
# * Set
# * Dictionary

# %% [markdown]
# ### List
# * 1D
# * store diffrent data types
# * allow duplicate
# * Ordered
# * indexing/ slicing is possible
# * mutable / changeable

# %%
name=[]
type(name)
# Out:
# list

# %%
list_names=["lathika","hello",2,5,3,"apple"]
print(list_names)
# Out:
# ['lathika', 'hello', 2, 5, 3, 'apple']

# %%
list_names[1]
# Out:
# 'hello'

# %%
# list_names[1:4]
# list_names[:4]
list_names[::-1]
# Out:
# ['apple', 3, 5, 2, 'hello', 'lathika']

# %%
st="lathika"
st[::-1]
# st[1:4]
# st[:6]
# Out:
# 'akihtal'

# %%
list_names[2]="hi"
list_names
# Out:
# ['lathika', 'hello', 'hi', 5, 3, 'apple']

# %%
list_names.append(6)
list_names
# Out:
# ['lathika', 'hello', 'hi', 5, 3, 'apple', 6]

# %%
list_names.insert(2,"hey")
list_names
# Out:
# ['lathika', 'hello', 'hey', 'hi', 5, 3, 'apple', 6]

# %%
list_names.extend("mango")
list_names
# Out:
# ['lathika', 'hello', 2, 5, 3, 'apple', 'm', 'a', 'n', 'g', 'o']

# %%
list_names.append("apple")

print(list_names)
# Out:
# ['o', 'g', 'n', 'a', 'm', 'o', 'g', 'n', 'a', 'm', 6, 'apple', 3, 5, 'hi', 'apple']

# %%
list_names.count("apple")
s
# Out:
# 2

# %%
list_names.reverse()
list_names
n
# Out:
# ['apple',
#  'o',
#  'g',
#  'n',
#  'a',
#  'm',
#  'o',
#  'g',
#  'n',
#  'a',
#  'm',
#  6,
#  'apple',
#  3,
#  5,
#  'hi',
#  'hey',
#  'hello',
#  'lathika']

# %%
list_names.remove("apple")
list_names
# Out:
# ['o',
#  'g',
#  'n',
#  'a',
#  'm',
#  'o',
#  'g',
#  'n',
#  'a',
#  'm',
#  6,
#  'apple',
#  3,
#  5,
#  'hi',
#  'hello',
#  'lathika']

# %%
list_names.pop()
# Out:
# 'lathika'

# %%
list_names
# Out:
# ['o',
#  'g',
#  'n',
#  'a',
#  'm',
#  'o',
#  'g',
#  'n',
#  'a',
#  'm',
#  6,
#  'apple',
#  3,
#  5,
#  'hi',
#  'hello']

# %%
list_names.pop()
# Out:
# 'hello'

# %%
new_list=[]
new_list=list_names.copy()
new_list
# Out:
# ['o', 'g', 'n', 'a', 'm', 'o', 'g', 'n', 'a', 'm', 6, 'apple', 3, 5, 'hi']

# %%
new_list.clear()

# %%
new_list
# Out:
# []

# %%
for i in list_names:
    print(i)
# Out:
# o
# g
# n
# a
# m
# o
# g
# n
# a
# m
# 6
# apple
# 3
# 5
# hi
# apple

# %%
num_1=[1,2,3]
num_2=[4,5,6]
num_1+num_2
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# ### Tuple
# * 1D
# * Ordered
# * store multiple data types
# * Allowed duplicate
# * immutable
# * indexing/ slicing is possible

# %%
sample=()
type(sample)
# Out:
# tuple

# %%
tuple_items=("Monitor","computer","mouse",22,9,"system")
tuple_items
# Out:
# ('Monitor', 'computer', 'mouse', 22, 9, 'system')

# %%
tuple_items[0]
# Out:
# 'Monitor'

# %%
tuple_items[1:3]
tuple_items[:5]
tuple_items[::-1]
# Out:
# ('system', 9, 22, 'mouse', 'computer', 'Monitor')

# %%
tuple_items[0]="laptop"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 tuple_items[0]="laptop"
#
# TypeError: 'tuple' object does not support item assignment

# %%
for i in tuple_items:
    print(i)
# Out:
# Monitor
# computer
# mouse
# 22
# 9
# system

# %%
list(tuple_items)
# Out:
# ['Monitor', 'computer', 'mouse', 22, 9, 'system']

# %%
t =(2,3,1,7,2)
sort = sorted(t)
print(sort)
# Out:
# [1, 2, 2, 3, 7]

# %%
good_tuple = (1, "apple")

print(hash(good_tuple))  # Works perfectly! Returns a unique integer.

# Valid use case: Using it as a dictionary key
# my_dict = {good_tuple: "fruit data"}
# Out:
# -4640241339025457283

# %% [markdown]
# ### Set
# * 1D
# * store multiple data types
# * unordered
# * duplicate not allowed
# * indexing and slicing is not allowed
# * partically changeable
# * mutable

# %%
set_items=set()
type(set_items)
set_items
# Out:
# set()

# %%
set_items={"lathika","hello","hii","lathika",1,2,3,4,"hey"}

# %%
set_items
# Out:
# {1, 2, 3, 4, 'hello', 'hey', 'hii', 'lathika'}

# %%
set_items[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 set_items[1]
#
# TypeError: 'set' object is not subscriptable

# %%
set_items["lathika"]=["lathi"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 set_items["lathika"]=["lathi"]
#
# TypeError: 'set' object does not support item assignment

# %%
set_items.add("mango")
set_items
# Out:
# {1, 2, 3, 4, 'hello', 'hey', 'hii', 'lathika', 'mango'}

# %%
new_set = set_items.copy()
new_set.clear()
new_set
# Out:
# set()

# %%
set_items.update("lathika")
set_items
# Out:
# {1,
#  2,
#  3,
#  4,
#  'a',
#  'h',
#  'hello',
#  'hey',
#  'hii',
#  'i',
#  'k',
#  'l',
#  'lathika',
#  'mango',
#  't'}

# %%
set_1={1,2,34}
set_2={4,5,6}
set_1.difference(set_2)
# Out:
# {1, 2, 34}

# %%
set_1.difference_update(set_2)

# %%
set_1.intersection(set_2)
# Out:
# set()

# %%
set_1.intersection_update(set_2)

# %%
set_items.discard("lathika")
set_items
# Out:
# {1, 2, 3, 4, 'a', 'h', 'hello', 'hey', 'hii', 'i', 'k', 'l', 'mango', 't'}

# %%
set_items.remove("hii")
set_items
# Out:
# {1, 2, 3, 4, 'a', 'h', 'hello', 'hey', 'i', 'k', 'l', 'mango', 't'}

# %%
set_items.pop()
# Out:
# 1

# %%
set_items
# Out:
# {2, 3, 4, 'a', 'h', 'hello', 'hey', 'i', 'k', 'l', 'mango', 't'}

# %%
set_1.union(set_2)
# Out:
# {4, 5, 6}

# %%
for i in set_items:
    print(i)
# Out:
# 2
# 3
# 4
# hello
# l
# a
# k
# hey
# i
# t
# mango
# h

# %% [markdown]
# ### Dictinary
# * 2D
# * Key - value pairs
# * Ordered
# * duplicats allowed values not allowed keys
# * indexing / slicing
# * using keys to access a value

# %%
dic_item ={}
type(dic_item)
# Out:
# dict

# %%
dic_items={"name":"lathika","age":22,"city":"chennai","City":"tamilnadu","name":"lath"}

# %%
dic_items
# Out:
# {'name': 'lath', 'age': 22, 'city': 'chennai', 'City': 'tamilnadu'}

# %%
dic_items["age"],["name"]
# Out:
# (22, ['name'])

# %%
bio={"Name":["kaviya","lathi","kushi"],"Age":[22,34,55],"city":["chenai","arani","tnager"]}
bio
# Out:
# {'Name': ['kaviya', 'lathi', 'kushi'],
#  'Age': [22, 34, 55],
#  'city': ['chenai', 'arani', 'tnager']}

# %%
a = [1, 2, 3, 4, 5, 6]
b = a[-1:0:-1]
# [::-1]
print(b)
# Out:
# [6, 5, 4, 3, 2]

# %%
bio.keys()
# Out:
# dict_keys(['Name', 'Age', 'city'])

# %%
bio.items()
# Out:
# dict_items([('Name', ['kaviya', 'lathi', 'kushi']), ('Age', [22, 34, 55]), ('city', ['chenai', 'arani', 'tnager'])])

# %%
bio.get("Name")
# Out:
# ['kaviya', 'lathi', 'kushi']

# %%
for i in bio:
    print(i)
for w in bio.values():
    print(w)
# Out:
# Name
# Age
# city
# ['kaviya', 'lathi', 'kushi']
# [22, 34, 55]
# ['chenai', 'arani', 'tnager']

# %%
bio["Age"][2]
# Out:
# 55

# %%
data = {"student":{
    "Name":["lathia","ram"],
    "age":[22,33]
},
       "staff":{
           "Name":["lathi","vicky"],
           "age":[22,22]
       }}
data
# Out:
# {'student': {'Name': ['lathia', 'ram'], 'age': [22, 33]},
#  'staff': {'Name': ['lathi', 'vicky'], 'age': [22, 22]}}

# %%
data["student"]["Name"][1]
# Out:
# 'ram'

# %%
for i in data:
    print(i)
# Out:
# student
# staff

# %%
for i in data.get("student"):
    print(i)
# Out:
# Name
# age

# %%
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'
