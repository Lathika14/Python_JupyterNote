# %% [markdown]
# ## if else Conditions
# * What is an if Statement?
# * The if statement is used to execute a block of code only when a specified condition is true.
# * Syntax
# *` if condition:
#   ` statements

# %%
num=int(input("enter the num: "))
if num>=18:
    print("vaild")
else:
    print("invaild")
# Out:
# enter the num:  1
# invaild

# %%
number = int(input("enter the number : "))
if 0 <= number <= 50:
             print("below 50")
elif 51 <= num <= 100:
             print("above 50")
else:
    print("nothing")
# Out:
# enter the number :  22
# below 50

# %% [markdown]
# ## Loops
# + What is a for Loop?
# + A for loop is used to iterate through a sequence such as:
# + List
# + Tuple
# + Dictionary
# + String
# + Dataset rows
# + Syntax
#
# for variable in sequence:
#
#  statements

# %%
num=[1,2,3,4,5]
for i in num:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(5,10):
    print(i)
# Out:
# 5
# 6
# 7
# 8
# 9

# %%
import pandas as pd
data = {
"Name": ["John", "Sara", "David"],
"Sales": [5000, 7000, 4000]}
df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 data = {
#       3 "Name": ["John", "Sara", "David"],
#       4 "Sales": [5000, 7000, 4000]}
#
# ModuleNotFoundError: No module named 'pandas'
