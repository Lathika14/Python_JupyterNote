# %%
import pandas as pd
print("done")
# Out:
# done

# %%
name = [ "lathika","tha","thww"]
n= pd.Series(name)
n
# Out:
# 0    lathika
# 1        tha
# 2       thww
# dtype: str

# %%
n1 = pd.Series(["lathika","tha","thww"],index=["name1","name2","name3"])
n1
# Out:
# name1    lathika
# name2        tha
# name3       thww
# dtype: str

# %%
name1 = ["lathika","tha","thww"]
n2=pd.Series(name1,index=range(1,4))
n2
# Out:
# 1    lathika
# 2        tha
# 3       thww
# dtype: str

# %%
bao= {"name": "Ran", "Age":33}

s=pd.Series(bao,index= [1,2])
s
# Out:
# 1    NaN
# 2    NaN
# dtype: object

# %%
bio= {"name": "Ran", "Age":33}

s=pd.DataFrame(bio,index=[1])
s
# Out:
#   name  Age
# 1  Ran   33

# %%
bio  = {"Name": ["Ram","jahs","insa"],"Age":[22,22,22]}
a = pd.DataFrame(bio)

# %%
bio
# Out:
# {'Name': ['Ram', 'jahs', 'insa'], 'Age': [22, 22, 22]}

# %%
a
# Out:
#    Name  Age
# 0   Ram   22
# 1  jahs   22
# 2  insa   22

# %%
a["Age"]
# Out:
# 0    22
# 1    22
# 2    22
# Name: Age, dtype: int64

# %%
a.head(1)
# Out:
#   Name  Age
# 0  Ram   22

# %%
a.tail(1)
# Out:
#    Name  Age
# 2  insa   22

# %%
print(a.to_string())
# Out:
#    Name  Age
# 0   Ram   22
# 1  jahs   22
# 2  insa   22
