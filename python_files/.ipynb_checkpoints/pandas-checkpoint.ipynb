# %% [markdown]
# ## Pandas
#
# + Python
# + Numpy
#     + DA
#     + DS
#     + AI/ML
#
# + Pands --> Panal Data
#     + series
#         + 1D -array
#     + Data frames
#         + multiple data
#  + Series/data frame --> store,maniplate,import,export,diaplay

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 3.0.3

# %%
age=[22,25,65,34,55]

# %%
series=pd.Series(age)
print(series)
# Out:
# 0    22
# 1    25
# 2    65
# 3    34
# 4    55
# dtype: int64

# %%
print(series.loc[1]) # index and we can create your own index
# Out:
# 25

# %%
series=pd.Series(age,index=["lathika","vinoth","kumar","siva","mani"])
print(series)
# Out:
# lathika    22
# vinoth     25
# kumar      65
# siva       34
# mani       55
# dtype: int64

# %%
print(series.loc["lathika"])
# Out:
# 22

# %%
print(series.iloc[1]) # index
# Out:
# 25

# %%
age ={
    "lathika" :23,
    "mani" :33,
    "sobana":22,
    "kumar":33
}

# %%
series=pd.Series(age)
print(series)
# Out:
# lathika    23
# mani       33
# sobana     22
# kumar      33
# dtype: int64

# %%
# we also do filtering

print(series[series>30])
print(series[series<30])
# Out:
# mani     33
# kumar    33
# dtype: int64
# lathika    23
# sobana     22
# dtype: int64

# %%
students ={
    "Name " : ["lathika","karthi","kali"],
    "Age": [22,24,25],
    "sub":["DA","DE","genai"]
}

# %%
df=pd.DataFrame(students)

# %%
print(df)
# Out:
#      Name   Age    sub
# 0  lathika   22     DA
# 1   karthi   24     DE
# 2     kali   25  genai

# %%
df = pd.DataFrame(students,index=[1,2,3])
print(df)
# Out:
#      Name   Age    sub
# 1  lathika   22     DA
# 2   karthi   24     DE
# 3     kali   25  genai

# %%
print(df.loc[1])
# Out:
# Name     lathika
# Age           22
# sub           DA
# Name: 1, dtype: object

# %%
print(df.iloc[1])
# Out:
# Name     karthi
# Age          24
# sub          DE
# Name: 2, dtype: object

# %%
df["phone"]=[1231223,241323,3241341]

# %%
print(df)
# Out:
#      Name   Age    sub    phone
# 1  lathika   22     DA  1231223
# 2   karthi   24     DE   241323
# 3     kali   25  genai  3241341

# %%
print(students)
# Out:
# {'Name ': ['lathika', 'karthi', 'kali'], 'Age': [22, 24, 25], 'sub': ['DA', 'DE', 'genai']}

# %%
s4 = pd.DataFrame({"Name ":"sobana","age":22,"sub":"DS"},index=[4])

# %%
df=pd.concat([df,s4])
print(df)
# Out:
#      Name    Age    sub      phone   age
# 1  lathika  22.0     DA  1231223.0   NaN
# 2   karthi  24.0     DE   241323.0   NaN
# 3     kali  25.0  genai  3241341.0   NaN
# 4   sobana   NaN     DS        NaN  22.0

# %%
students = pd.DataFrame([
    {"Name ":"sobi","Age":22,"sub":"DS"},
    {"Name":"ragi","Age":26,"sub":"QA"}
]
                        ,index=[5,4])

# %%
df = pd.concat([df,students])
print(df)
# Out:
#      Name    Age    sub      phone   age  Name
# 1  lathika  22.0     DA  1231223.0   NaN   NaN
# 2   karthi  24.0     DE   241323.0   NaN   NaN
# 3     kali  25.0  genai  3241341.0   NaN   NaN
# 4   sobana   NaN     DS        NaN  22.0   NaN
# 5     sobi  22.0     DS        NaN   NaN   NaN
# 4      NaN  26.0     QA        NaN   NaN  ragi

# %%
d =df.loc[(df['Age']>20) | (df["Age"]<25)]
print(d)
# Out:
#      Name    Age    sub      phone  age  Name
# 1  lathika  22.0     DA  1231223.0  NaN   NaN
# 2   karthi  24.0     DE   241323.0  NaN   NaN
# 3     kali  25.0  genai  3241341.0  NaN   NaN
# 5     sobi  22.0     DS        NaN  NaN   NaN
# 4      NaN  26.0     QA        NaN  NaN  ragi

# %%
d =df.loc[(df["Name"].str.startswith("k")) ]
print(d)
# Out:
# Empty DataFrame
# Columns: [Name , Age, sub, phone, age, Name]
# Index: []

# %%
print(df["Name"].to_list())
# Out:
# [nan, nan, nan, nan, nan, 'ragi']

# %%
d = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Documents\\CourseNotes\\Data.csv")

# %%
print(d.head(2))
# Out:
#     id    name  age department  salary
# 0  101    Ravi   25         IT   35000
# 1  102  Anitha   28         HR   40000

# %%
d.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          4 non-null      int64
#  1   name        4 non-null      str
#  2   age         4 non-null      int64
#  3   department  4 non-null      str
#  4   salary      4 non-null      int64
# dtypes: int64(3), str(2)
# memory usage: 292.0 bytes

# %%
d.describe()
# Out:
#                id        age        salary
# count    4.000000   4.000000      4.000000
# mean   102.500000  27.250000  39500.000000
# std      1.290994   2.217356   4203.173404
# min    101.000000  25.000000  35000.000000
# 25%    101.750000  25.750000  37250.000000
# 50%    102.500000  27.000000  39000.000000
# 75%    103.250000  28.500000  41250.000000
# max    104.000000  30.000000  45000.000000

# %%
d.to_string() # all rows print
# Out:
# '    id    name  age department  salary\n0  101    Ravi   25         IT   35000\n1  102  Anitha   28         HR   40000\n2  103   Kumar   30    Finance   45000\n3  104   Divya   26         IT   38000'

# %%
print(d["id"].to_string())
# Out:
# 0    101
# 1    102
# 2    103
# 3    104

# %%
print(d[["id","name"]].to_string())
# Out:
#     id    name
# 0  101    Ravi
# 1  102  Anitha
# 2  103   Kumar
# 3  104   Divya

# %%
import pandas as pd

# %%
data = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Documents\\CourseNotes\\employee_data_cleaning_practice_200_rows.csv")

# %%
print(data)
# Out:
#     Employee_ID Employee_Name   Age  Gender         Department        City  \
# 0             1   Sneha Kumar  38.0  Female            finance   Bangalore
# 1             2   Arun Sharma  34.0       F            finance     Chennai
# 2             3    Anitha Rao  17.0    male         Operations     chennai
# 3             4  Sneha Sharma  45.0    Male          Marketing     Chennai
# 4             5     Sneha Das  26.0       F         Operations     Chennai
# ..          ...           ...   ...     ...                ...         ...
# 195         196     Kavya Rao  51.0    Male          Marketing       Delhi
# 196         197   Nisha Kumar  32.0       M   Human Resources      chennai
# 197         198     Arun Iyer   0.0     NaN   Human Resources         Pune
# 198         199  Suresh Reddy  28.0       M          Marketing  BANGALORE
# 199         200   Gokul Reddy  32.0  female            finance     chennai
#
# ...

# %%
print(data.to_string())
# Out:
#     Employee_ID    Employee_Name   Age  Gender         Department        City                         Email Employment_Type     Salary Joining_Date  Performance_Score  Attendance_Percentage
# 0             1      Sneha Kumar  38.0  Female            finance   Bangalore        sneha.kumar1@gmail.com       Part time      53000   2020-07-03                NaN                   75.0
# 1             2      Arun Sharma  34.0       F            finance     Chennai      arun.sharma2@company.com        contract      53000   2023-09-01                6.0                    NaN
# 2             3       Anitha Rao  17.0    male         Operations     chennai         anitha.rao3@gmail.com       Part-Time      58000   2018-01-27                4.0                  100.0
# 3             4     Sneha Sharma  45.0    Male          Marketing     Chennai       sneha.sharma4@yahoo.com        contract      33000   2022-01-10                0.0                   -5.0
# ...

# %%
print(data.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee_ID            200 non-null    str
#  1   Employee_Name          200 non-null    str
#  2   Age                    182 non-null    float64
#  3   Gender                 177 non-null    str
#  4   Department             197 non-null    str
#  5   City                   200 non-null    str
#  6   Email                  200 non-null    str
#  7   Employment_Type        164 non-null    str
#  8   Salary                 193 non-null    str
#  9   Joining_Date           196 non-null    str
#  10  Performance_Score      180 non-null    float64
#  11  Attendance_Percentage  180 non-null    float64
# dtypes: float64(3), str(9)
# memory usage: 18.9 KB
# None

# %%
data.describe()
# Out:
#               Age  Performance_Score  Attendance_Percentage
# count  182.000000         180.000000             180.000000
# mean    38.137363           3.150000              77.333333
# std     12.475294           1.962569              35.138990
# min      0.000000           0.000000              -5.000000
# 25%     29.000000           2.000000              80.000000
# 50%     40.000000           3.500000              90.000000
# 75%     48.000000           5.000000             100.000000
# max     65.000000           6.000000             105.000000

# %%
data.head()
# Out:
#   Employee_ID Employee_Name   Age  Gender  Department       City  \
# 0           1   Sneha Kumar  38.0  Female     finance  Bangalore
# 1           2   Arun Sharma  34.0       F     finance    Chennai
# 2           3    Anitha Rao  17.0    male  Operations    chennai
# 3           4  Sneha Sharma  45.0    Male   Marketing    Chennai
# 4           5     Sneha Das  26.0       F  Operations    Chennai
#
#                       Email Employment_Type  Salary Joining_Date  \
# 0    sneha.kumar1@gmail.com       Part time   53000   2020-07-03
# 1  arun.sharma2@company.com        contract   53000   2023-09-01
# 2     anitha.rao3@gmail.com       Part-Time   58000   2018-01-27
# 3   sneha.sharma4@yahoo.com        contract   33000   2022-01-10
# 4    sneha.das5@company.com        contract  103000   2021-04-15
#
#    Performance_Score  Attendance_Percentage
# 0                NaN                   75.0
# 1                6.0                    NaN
# 2                4.0                  100.0
# ...

# %%
print(data["Age"].to_string()) # column only
# Out:
# 0      38.0
# 1      34.0
# 2      17.0
# 3      45.0
# 4      26.0
# 5      26.0
# 6      25.0
# 7      41.0
# 8      46.0
# 9      48.0
# 10     48.0
# 11     55.0
# 12     32.0
# 13     21.0
# 14      0.0
# 15     54.0
# 16     28.0
# 17     35.0
# 18      NaN
# 19     47.0
# 20     33.0
# 21     27.0
# 22     46.0
# 23     52.0
# 24     51.0
# 25     36.0
# 26     54.0
# 27     25.0
# 28     43.0
# 29     21.0
# 30     39.0
# 31     48.0
# 32     21.0
# 33     29.0
# 34     47.0
# 35     36.0
# 36     43.0
# 37      NaN
# 38     65.0
# 39     21.0
# 40     53.0
# 41     32.0
# 42     65.0
# 43     26.0
# 44     30.0
# 45     46.0
# 46      NaN
# 47     49.0
# 48     38.0
# 49     30.0
# 50     47.0
# 51     40.0
# 52     22.0
# 53     22.0
# 54     45.0
# 55     22.0
# 56      NaN
# 57     31.0
# 58     46.0
# 59     43.0
# 60     44.0
# 61     51.0
# 62     36.0
# 63     43.0
# 64     52.0
# 65     46.0
# 66     42.0
# 67     55.0
# 68     39.0
# 69     29.0
# 70     24.0
# ...

# %%
print(data[["Age","Gender"]].to_string())
# Out:
#       Age  Gender
# 0    38.0  Female
# 1    34.0       F
# 2    17.0    male
# 3    45.0    Male
# 4    26.0       F
# 5    26.0  female
# 6    25.0       M
# 7    41.0    male
# 8    46.0       F
# 9    48.0     NaN
# 10   48.0     NaN
# 11   55.0   Male
# 12   32.0       F
# 13   21.0  female
# 14    0.0       M
# 15   54.0    male
# 16   28.0       F
# 17   35.0       F
# 18    NaN       F
# 19   47.0   Male
# 20   33.0    male
# 21   27.0       F
# 22   46.0    male
# 23   52.0    Male
# 24   51.0  Female
# 25   36.0    Male
# 26   54.0    male
# 27   25.0  Female
# 28   43.0     NaN
# 29   21.0    male
# 30   39.0    male
# 31   48.0    male
# 32   21.0    Male
# 33   29.0       F
# 34   47.0       M
# 35   36.0    Male
# 36   43.0   Male
# 37    NaN  Female
# 38   65.0  Female
# 39   21.0   Male
# 40   53.0    male
# 41   32.0    Male
# 42   65.0     NaN
# 43   26.0  Female
# 44   30.0  Female
# 45   46.0   Male
# 46    NaN  female
# 47   49.0       F
# 48   38.0    male
# ...

# %%
print(data.loc[1])
# Out:
# Employee_ID                                     2
# Employee_Name                         Arun Sharma
# Age                                          34.0
# Gender                                          F
# Department                                finance
# City                                      Chennai
# Email                    arun.sharma2@company.com
# Employment_Type                          contract
# Salary                                      53000
# Joining_Date                           2023-09-01
# Performance_Score                             6.0
# Attendance_Percentage                         NaN
# Name: 1, dtype: object

# %%
data = pd.read_csv("C:\\Users\\Admin\\OneDrive\\Documents\\CourseNotes\\employee_data_cleaning_practice_200_rows.csv",index_col="Employee_ID")

# %%
print(data.iloc[2])
# Out:
# Employee_Name                       Anitha Rao
# Age                                       17.0
# Gender                                    male
# Department                          Operations
# City                                   chennai
# Email                    anitha.rao3@gmail.com
# Employment_Type                      Part-Time
# Salary                                   58000
# Joining_Date                        2018-01-27
# Performance_Score                          4.0
# Attendance_Percentage                    100.0
# Name: 3, dtype: object

# %%
print(data.to_string())
# Out:
#                Employee_Name   Age  Gender         Department        City                         Email Employment_Type     Salary Joining_Date  Performance_Score  Attendance_Percentage
# Employee_ID
# 1                Sneha Kumar  38.0  Female            finance   Bangalore        sneha.kumar1@gmail.com       Part time      53000   2020-07-03                NaN                   75.0
# 2                Arun Sharma  34.0       F            finance     Chennai      arun.sharma2@company.com        contract      53000   2023-09-01                6.0                    NaN
# 3                 Anitha Rao  17.0    male         Operations     chennai         anitha.rao3@gmail.com       Part-Time      58000   2018-01-27                4.0                  100.0
# 4               Sneha Sharma  45.0    Male          Marketing     Chennai       sneha.sharma4@yahoo.com        contract      33000   2022-01-10                0.0                   -5.0
# ...

# %%
print(data.loc["2",["Employee_Name","Age"]])
# Out:
# Employee_Name    Arun Sharma
# Age                     34.0
# Name: 2, dtype: object

# %%
print(data.loc["2":"10",["Employee_Name","Age"]])
# Out:
#              Employee_Name   Age
# Employee_ID
# 2              Arun Sharma  34.0
# 3               Anitha Rao  17.0
# 4             Sneha Sharma  45.0
# 5                Sneha Das  26.0
# 6              Anitha Iyer  26.0
# 7               Vijay Iyer  25.0
# 8              Nisha Reddy  41.0
# 9                Vijay Rao  46.0
# 10           Suresh Joseph  48.0

# %%
print(data.iloc[0])
# Out:
# Employee_Name                       Sneha Kumar
# Age                                        38.0
# Gender                                   Female
# Department                              finance
# City                                  Bangalore
# Email                    sneha.kumar1@gmail.com
# Employment_Type                       Part time
# Salary                                    53000
# Joining_Date                         2020-07-03
# Performance_Score                           NaN
# Attendance_Percentage                      75.0
# Name: 1, dtype: object

# %%
print(data.iloc[0:5:2,1:4])
# Out:
#               Age  Gender  Department
# Employee_ID
# 1            38.0  Female     finance
# 3            17.0    male  Operations
# 5            26.0       F  Operations

# %% [markdown]
# ## filtering

# %%
f = data.copy()

# %%
f.to_string()
# Out:
# '               Employee_Name   Age  Gender         Department        City                         Email Employment_Type     Salary Joining_Date  Performance_Score  Attendance_Percentage\nEmployee_ID                                                                                                                                                                              \n1                Sneha Kumar  38.0  Female            finance   Bangalore        sneha.kumar1@gmail.com       Part time      53000   2020-07-03                NaN                   75.0\n2                Arun Sharma  34.0       F            finance     Chennai      arun.sharma2@company.com        contract      53000   2023-09-01                6.0                    NaN\n3                 Anitha Rao  17.0    male         Operations     chennai         anitha.rao3@gmail.com       Part-Time      58000   2018-01-27                4.0                  100.0\n4               Sneha Sharma  45.0    Male          Marketing 
# ...

# %%
f= data[data["Age"]>=40]
print(f)
# Out:
#              Employee_Name   Age Gender Department       City  \
# Employee_ID
# 4             Sneha Sharma  45.0   Male  Marketing    Chennai
# 8              Nisha Reddy  41.0   male         it      Delhi
# 9                Vijay Rao  46.0      F    Finance       Pune
# 10           Suresh Joseph  48.0    NaN    Finance     Mumbai
# 11           Karthik Patel  48.0    NaN      SALES    chennai
# ...                    ...   ...    ...        ...        ...
# 184            Priya Patel  42.0      M      SALES  Hyderabad
# 185            Ajay Joseph  40.0    NaN    finance   Hyderbad
# 186             Arun Singh  42.0   Male  Marketing    Chennai
# E189           Hari Joseph  51.0      F    finance  Hyderabad
# 196              Kavya Rao  51.0   Male  Marketing      Delhi
#
#                                   Email Employment_Type     Salary  \
# Employee_ID
# 4               sneha.sharma4@yahoo.com        contract      33000
# ...

# %%
f=data[data["Gender"]!="Female"]

# %%
f
# Out:
#             Employee_Name   Age  Gender         Department        City  \
# Employee_ID
# 2             Arun Sharma  34.0       F            finance     Chennai
# 3              Anitha Rao  17.0    male         Operations     chennai
# 4            Sneha Sharma  45.0    Male          Marketing     Chennai
# 5               Sneha Das  26.0       F         Operations     Chennai
# 6             Anitha Iyer  26.0  female   Human Resources         Pune
# ...                   ...   ...     ...                ...         ...
# 196             Kavya Rao  51.0    Male          Marketing       Delhi
# 197           Nisha Kumar  32.0       M   Human Resources      chennai
# 198             Arun Iyer   0.0     NaN   Human Resources         Pune
# 199          Suresh Reddy  28.0       M          Marketing  BANGALORE
# 200           Gokul Reddy  32.0  female            finance     chennai
#
#                                    Email Employment_Type  Salary Joining_Date  \
# Employee_ID
# ...

# %%
f= data[(data["Gender"]=="Female") & (data["Age"]>=40)]
f
# Out:
#             Employee_Name   Age  Gender  Department       City  \
# Employee_ID
# 25           Priya Joseph  51.0  Female     finance    Chennai
# 39           Priya Sharma  65.0  Female          it      Delhi
# 59              Gokul Das  46.0  Female       Sales    Chennai
# 120           Vijay Patel  51.0  Female  Operations   Hyderbad
# 131             Rahul Das  40.0  Female     Finance      Delhi
# 132            Hari Reddy  43.0  Female       Sales  Hyderabad
# E135            Meena Rao  49.0  Female          HR       Pune
# 142           Divya Reddy  42.0  Female     Finance  Hyderabad
# 182             Rahul Das  53.0  Female       SALES    Chennai
#
#                                   Email Employment_Type  Salary Joining_Date  \
# Employee_ID
# 25             priya.joseph25@gmail.com             NaN   98000   2023-12-16
# 39           priya.sharma39@company.com       full time   83000   2021-11-16
# ...

# %% [markdown]
# ## Aggregate

# %%
data.mean(numeric_only=True)
# Out:
# Age                      38.137363
# Performance_Score         3.150000
# Attendance_Percentage    77.333333
# dtype: float64

# %%
data.min(numeric_only=True)
# Out:
# Age                      0.0
# Performance_Score        0.0
# Attendance_Percentage   -5.0
# dtype: float64

# %%
data.count(numeric_only=True)
# Out:
# Age                      182
# Performance_Score        180
# Attendance_Percentage    180
# dtype: int64

# %%
data["Salary"].count()
# Out:
# np.int64(193)

# %%
data["Salary"].min()
# Out:
# '-25000'

# %%
data["Salary"].max()
# Out:
# '98000'

# %%
data["Salary"].
# Out:
# '530005300058000330001030005300011300023000118000108000113000580009800011300028000113000530002800010800088000103000230002300038000980007800068000180002800045000 INR5800033000230001130005800063000780008300098000630001130001180006300018000530005300043000880005300023000780007800078000680000113000113000-2500010300011800045000 INR8800058000103000-2500073000-2500053000118000580002800010800043000230003300063000113000118000-2500078000118000530003300038000580006800083000108000580002300045000 INR3800093000430007800018000118000730007300028000880001130002300058000118000230006800038000980009800010300008300083000730005300018000380008300045000 INR5800053000330002800078000-2500007300011800093000230000330001130003300073000280009300023000930004300033000730006800011300033000113000530001800045000 INR48000630006800083000113000118000530002800093000-25000-250003300011300068000230002800010800058000680006800011300063000930007800088000730009300010800045000 INR0180000430001030000-250003800083000118000830001130
# ...

# %%
# group by

# %%
group = data.groupby("Employment_Type")
group

# %%
print(group.min(numeric_only=True))
# Out:
#                   Age  Performance_Score  Attendance_Percentage
# Employment_Type
# Contract          0.0                0.0                   -5.0
# Full-Time         0.0                0.0                   -5.0
# Part time        22.0                0.0                   -5.0
# Part-Time         0.0                0.0                   -5.0
# contract         17.0                0.0                   -5.0
# full time         0.0                0.0                   -5.0

# %%
## cleaning

# %%
d = data.dropna(subset= ["Performance_Score"])

# %%
d
# Out:
#             Employee_Name   Age  Gender         Department        City  \
# Employee_ID
# 2             Arun Sharma  34.0       F            finance     Chennai
# 3              Anitha Rao  17.0    male         Operations     chennai
# 4            Sneha Sharma  45.0    Male          Marketing     Chennai
# 5               Sneha Das  26.0       F         Operations     Chennai
# 6             Anitha Iyer  26.0  female   Human Resources         Pune
# ...                   ...   ...     ...                ...         ...
# 195          Anitha Kumar  27.0       M                 HR  BANGALORE
# 196             Kavya Rao  51.0    Male          Marketing       Delhi
# 197           Nisha Kumar  32.0       M   Human Resources      chennai
# 198             Arun Iyer   0.0     NaN   Human Resources         Pune
# 199          Suresh Reddy  28.0       M          Marketing  BANGALORE
#
#                                    Email Employment_Type  Salary Joining_Date  \
# Employee_ID
# ...

# %%
d = data.fillna({"Performance_Score":0})

# %%
d
# Out:
#             Employee_Name   Age  Gender         Department        City  \
# Employee_ID
# 1             Sneha Kumar  38.0  Female            finance   Bangalore
# 2             Arun Sharma  34.0       F            finance     Chennai
# 3              Anitha Rao  17.0    male         Operations     chennai
# 4            Sneha Sharma  45.0    Male          Marketing     Chennai
# 5               Sneha Das  26.0       F         Operations     Chennai
# ...                   ...   ...     ...                ...         ...
# 196             Kavya Rao  51.0    Male          Marketing       Delhi
# 197           Nisha Kumar  32.0       M   Human Resources      chennai
# 198             Arun Iyer   0.0     NaN   Human Resources         Pune
# 199          Suresh Reddy  28.0       M          Marketing  BANGALORE
# 200           Gokul Reddy  32.0  female            finance     chennai
#
#                                    Email Employment_Type  Salary Joining_Date  \
# Employee_ID
# ...

# %%
data["Gender"]=data["Gender"].replace({"f":"Female"})
data
# Out:
#             Employee_Name   Age  Gender         Department        City  \
# Employee_ID
# 1             Sneha Kumar  38.0  Female            finance   Bangalore
# 2             Arun Sharma  34.0       F            finance     Chennai
# 3              Anitha Rao  17.0    male         Operations     chennai
# 4            Sneha Sharma  45.0    Male          Marketing     Chennai
# 5               Sneha Das  26.0       F         Operations     Chennai
# ...                   ...   ...     ...                ...         ...
# 196             Kavya Rao  51.0    Male          Marketing       Delhi
# 197           Nisha Kumar  32.0       M   Human Resources      chennai
# 198             Arun Iyer   0.0     NaN   Human Resources         Pune
# 199          Suresh Reddy  28.0       M          Marketing  BANGALORE
# 200           Gokul Reddy  32.0  female            finance     chennai
#
#                                    Email Employment_Type  Salary Joining_Date  \
# Employee_ID
# ...

# %%
data["Gender"]=data["Gender"].replace({"F":"Female"})

# %%
data
# Out:
#             Employee_Name   Age  Gender         Department        City  \
# Employee_ID
# 1             Sneha Kumar  38.0  Female            finance   Bangalore
# 2             Arun Sharma  34.0  Female            finance     Chennai
# 3              Anitha Rao  17.0    male         Operations     chennai
# 4            Sneha Sharma  45.0    Male          Marketing     Chennai
# 5               Sneha Das  26.0  Female         Operations     Chennai
# ...                   ...   ...     ...                ...         ...
# 196             Kavya Rao  51.0    Male          Marketing       Delhi
# 197           Nisha Kumar  32.0       M   Human Resources      chennai
# 198             Arun Iyer   0.0     NaN   Human Resources         Pune
# 199          Suresh Reddy  28.0       M          Marketing  BANGALORE
# 200           Gokul Reddy  32.0  female            finance     chennai
#
#                                    Email Employment_Type  Salary Joining_Date  \
# Employee_ID
# ...

# %%
data["Gender"]=data["Gender"].replace({"male":"Male","M":"Male","m":"Male"})

# %%
data
# Out:
#             Employee_Name   Age  Gender         Department        City  \
# Employee_ID
# 1             Sneha Kumar  38.0  Female            finance   Bangalore
# 2             Arun Sharma  34.0  Female            finance     Chennai
# 3              Anitha Rao  17.0    Male         Operations     chennai
# 4            Sneha Sharma  45.0    Male          Marketing     Chennai
# 5               Sneha Das  26.0  Female         Operations     Chennai
# ...                   ...   ...     ...                ...         ...
# 196             Kavya Rao  51.0    Male          Marketing       Delhi
# 197           Nisha Kumar  32.0    Male   Human Resources      chennai
# 198             Arun Iyer   0.0     NaN   Human Resources         Pune
# 199          Suresh Reddy  28.0    Male          Marketing  BANGALORE
# 200           Gokul Reddy  32.0  female            finance     chennai
#
#                                    Email Employment_Type  Salary Joining_Date  \
# Employee_ID
# ...

# %%
import numpy as np
data["Age"]=data["Age"].astype(np.int64)
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[82], line 2
#       1 import numpy as np
# ----> 2 data["Age"]=data["Age"].astype(np.int64)
#
# File ~\Lib\site-packages\pandas\core\generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537             results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6538
#    6539         else:
#    6540             # else, only a single dtype is given
# -> 6541             new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543             return res.__finalize__(self, method="astype")
#    6544
#
# File ~\Lib\site-packages\pandas\core\internals\managers.py:614, in BaseBlockManager.astype(self, dtype, errors)
#     613 def astype(self, dtype, errors: str = "raise") -> Self:
# ...

# %%
d = data.drop_duplicates()
d
# Out:
#             Employee_Name   Age  Gender         Department        City  \
# Employee_ID
# 1             Sneha Kumar  38.0  Female            finance   Bangalore
# 2             Arun Sharma  34.0  Female            finance     Chennai
# 3              Anitha Rao  17.0    Male         Operations     chennai
# 4            Sneha Sharma  45.0    Male          Marketing     Chennai
# 5               Sneha Das  26.0  Female         Operations     Chennai
# ...                   ...   ...     ...                ...         ...
# 196             Kavya Rao  51.0    Male          Marketing       Delhi
# 197           Nisha Kumar  32.0    Male   Human Resources      chennai
# 198             Arun Iyer   0.0     NaN   Human Resources         Pune
# 199          Suresh Reddy  28.0    Male          Marketing  BANGALORE
# 200           Gokul Reddy  32.0  female            finance     chennai
#
#                                    Email Employment_Type  Salary Joining_Date  \
# Employee_ID
# ...

# %%
excel = pd.read_excel("C:\\Users\\Admin\\OneDrive\\Documents\\CourseNotes\\DA\\excel\\Data_Analyst_Practice_Dataset.xlsx",sheet_name="Sheet1")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 excel = pd.read_excel("C:\\Users\\Admin\\OneDrive\\Documents\\CourseNotes\\DA\\excel\\Data_Analyst_Practice_Dataset.xlsx",sheet_name="Sheet1")
#
# File ~\Lib\site-packages\pandas\io\excel\_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
# ...

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
excel.head()
# Out:
#   OrderID        Date CustomerID ProductID EmpID        City State  Qty  \
# 0   O0001  2026-02-07       C205      P004  E026  Coimbatore    TN    1
# 1   O0002  2026-03-15       C172      P002  E017   Hyderabad    TS    7
# 2   O0003  2026-03-15       C042      P004  E096        Pune    MH    2
# 3   O0004  2026-05-28       C125      P002  E085   Bangalore    KA    9
# 4   O0005  2026-05-08       C160      P005  E053     Chennai    TN    9
#
#    UnitPrice  Discount   Sales
# 0      15000         0   15000
# 1        700         0    4900
# 2      15000        10   27000
# 3        700        10    5670
# 4      18000         5  153900

# %%
import os

path = r"C:\Users\Admin\OneDrive\Documents\CourseNotes\DA\excel\Data_Analyst_Practice_Dataset.xlsx"

print(os.path.exists(path))
# Out:
# True
