# %%
import random
random.

# %% [markdown]
# ## Strings Functions

# %%
first_name ="jonn"
se_name="mike"
num_1="34"
num_2="22"
name=first_name+se_name
print(name)
print(num_1+num_2)
# Out:
# Jonnmike
# 3422

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
print(name.capitalize())
print(name.count("o"))
print(name.upper())
print(name.lower())
print(name.casefold())
print(name.replace("o","!"))
print(name)
print(name.endswith("i"))
print(name.find("J"))
print(name.strip())
# Out:
# Jonnmike
# 1
# JONNMIKE
# jonnmike
# jonnmike
# J!nnmike
# Jonnmike
# False
# 0
# Jonnmike

# %%
word="hello"
age="12"
name="this is python"
print(word.strip())
print(age.isalpha())
print(age.isdigit())
print(word.center(20))
print(name.split())
name.
# Out:
# hello
# False
# True
#        hello
# ['this', 'is', 'python']
# <function str.strip(chars=None, /)>

# %%
print("Hello, {1}. You are {0}.".format(25, "Bob"))
print("Hello, {}. You are {}.".format( 25,"BOb"))
print("Coordinates: {lat}, {lon}".format(lat="37.77N", lon="122.41W"))
# Out:
# Hello, Bob. You are 25.
# Hello, 25. You are BOb.
# Coordinates: 37.77N, 122.41W
