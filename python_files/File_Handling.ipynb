# %%
file=open("Text.txt","w")

# %%
file.write("Hello this is file handling\nthis is python file handling")
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 file.write("Hello this is file handling\nthis is python file handling")
#
# UnsupportedOperation: not writable

# %%
file.close()

# %%
file=open("Text.txt","r")

# %%
con= file.read()

# %%
print(con)
# Out:
# Hello this is file handling
# this is phthon  file handling

# %%
file = open("Text.txt","w")

# %%
file.write("this is python")
# Out:
# 14

# %%
file.close()

# %%
file=open("Text.txt","r")

# %%
cont=file.read()

# %%
print(cont)
# Out:
# this is python

# %%
file=open("Text.txt","a")
file.write("\nthis is file handling")
# Out:
# 22

# %%
file.close()

# %%
file=open("Text.txt","r")

# %%
con=file.read()

# %%
print(con)
# Out:
# this is python
# this is file handling

# %%
b_file=open("API Testing.pdf","rb")

# %%
con=b_file.read()
print(con)
# Out:
# b''

# %%
feedback=input("enter the feedback :")
file = open("feedback.txt","a")
file.write(f"\n{feedback}")
file.close()
# Out:
# enter the feedback : this is python file handling

# %%
with open("feedback.txt","r") as file:
    for i in file:
        print(i)
# Out:
# this is feedback file
#
# this is python file handling
