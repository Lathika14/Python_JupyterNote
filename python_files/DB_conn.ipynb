# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector
print("Import Done")
# Out:
# Import Done

# %%
import mysql.connector
print("Import Done")
# Out:
# Import Done

# %%
conn= mysql.connector.connect(
    host="127.0.0.1",
    user="root",
    password="Vicky@1405",
    database="learn")
print("data bases connected")
# Out:
# data bases connected

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import mysql.connector
print("Import Done")
# Out:
# Import Done

# %%
conn= mysql.connector.connect(
    host="127.0.0.1",
    user="root",
    password="Vicky@1405",
    database="data")
print("data bases connected")
# Out:
# data bases connected

# %%
cursor = conn.cursor()

# %%
cursor.execute("select * from department")

# %%
cursor.execute("select * from department where Dept_ID = 1" )

# %%
for row in cursor.fetchall():
    print(row)
# Out:
# (1, 'HR')
# (2, 'IT')
# (3, 'Finance')

# %%
type(row)
# Out:
# tuple

# %%
datas=cursor.fetchall()

# %%
cursor.execute("select * from department")

# %%
for row in datas:
    print(row)
# Out:
# (1, 'HR')
# (2, 'IT')
# (3, 'Finance')

# %%
print(cursor.fetchone())
# Out:
# (1, 'HR')

# %%
item =cursor.fetchall()

# %%
for i in item:
    print(i)

# %%
cursor.execute("select * from department")

# %%
dept = cursor.fetchall()

# %%
for r in dept:
    print(r)
# Out:
# (1, 'HR')
# (2, 'IT')
# (3, 'Finance')

# %%
import pandas as pd
print("done")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\Admin\Lib\site-packages\numpy\_core\__init__.py:24
#      23 try:
# ---> 24     from . import multiarray
#      25 except ImportError as exc:
#
# File c:\Users\Admin\Lib\site-packages\numpy\_core\multiarray.py:11
#       9 import functools
# ---> 11 from . import _multiarray_umath, overrides
#      12 from ._multiarray_umath import *
#
# File c:\Users\Admin\Lib\site-packages\numpy\_core\overrides.py:6
#       4 import inspect
# ----> 6 from numpy._core._multiarray_umath import (
#       7     _ArrayFunctionDispatcher,
#       8     _get_implementing_args,
#       9     add_docstring,
#      10 )
#      11 from numpy._utils import set_module  # noqa: F401
#
# ModuleNotFoundError: No module named 'numpy._core._multiarray_umath'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
cursor.execute("select * from department")
print("done")
# Out:
# done

# %%
name = cursor.fetchall()

# %%
import pandas as pd
print("done")
# Out:
# done

# %%
ds = pd.DataFrame(name, columns=["Dept_ID", "Dept_Name"])
print(ds)
# Out:
#    Dept_ID Dept_Name
# 0        1        HR
# 1        2        IT
# 2        3   Finance

# %%
print(ds.to_string()) # all data show
# Out:
#    Dept_ID Dept_Name
# 0        1        HR
# 1        2        IT
# 2        3   Finance
