# %% [markdown]
# ### Operators
#
# + Arithmetic Operators
# +

# %%
5+5
# Out:
# 10

# %%
5-5
# Out:
# 0

# %%
5*5
# Out:
# 25

# %%
11/2
# Out:
# 5.5

# %%
11//2
# Out:
# 5

# %%
5%2
# Out:
# 1

# %%
10**2
# Out:
# 100

# %%
5==7
# Out:
# False

# %%
3!=4
# Out:
# True

# %%
3<=3
# Out:
# True

# %%
63>=2321
# Out:
# False

# %%
(5==5)or(9==9)
# Out:
# True

# %%
not(4<5)
# Out:
# False

# %%
a=9

a=a+1
a
a=a+1
a
# Out:
# 11

# %%
a*=1
a
# Out:
# 11.0

# %%
w="hello"
print("l" not in w)
# Out:
# False

# %%
li=[1,2,3,4,5,6,7]
