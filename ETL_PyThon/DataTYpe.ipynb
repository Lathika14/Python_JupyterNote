# %% [markdown]
# ## Data Types
#
# + Integer
# + string
# + float
# + boolean
# + None

# %%
a=12
print(type(a))
# Out:
# <class 'int'>

# %%
fl = 23.45
print(type(fl))
# Out:
# <class 'float'>

# %%
name="Lathika"

type(name)
name
# Out:
# 'Lathika'

# %%
n=True
type(n)
# Out:
# bool

# %%
b=None
type(b)
# Out:
# NoneType

# %%
na=[1,2,3,4,5,"hello"]
type(na)
# Out:
# list

# %%
n=(1,2,3,4)
type(n)
# Out:
# tuple

# %%
n={1,3,4,5}
n
type(n)
# Out:
# set

# %%
dic={"name" : "lathika"}
type(dic)
# Out:
# dict

# %%
a="10"
b=int(a)
type(b)
type(a)

c=1223
type(c)
d=float(c)
type(d)
# Out:
# float
