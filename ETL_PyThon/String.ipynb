# %% [markdown]
# ## String

# %%
name="lathika"
print(name)
# Out:
# lathika

# %%
name.capitalize()
# Out:
# 'Lathika'

# %%
s="This IS CAsefold string MEthod"
print(s.capitalize())
print(s.casefold())
# Out:
# This is casefold string method
# this is casefold string method

# %%
print("Hii".center(10," "))
# Out:
#    Hii

# %%
print("Banana".count("B"))
# Out:
# 1

# %%
print("Banana".endswith("ana"))
# Out:
# True

# %%
print("a\tn".expandtabs(8))
# Out:
# a       n

# %%
print("hii".find("o"))
# Out:
# -1

# %%
print("{} and {}".format("hii","heelo"))
# Out:
# hii and heelo

# %%
print("this is python".index("0"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 print("this is python".index("0"))
#
# ValueError: substring not found

# %%
print("safcj  *(*())*".isalnum())
# Out:
# False

# %%
print("fasndcjkfd".isalpha())
# Out:
# True

# %%
print("₹".isascii())
# Out:
# False

# %%
print("34sda".isdecimal())
# Out:
# False

# %%
print("2222".isidentifier())
# Out:
# False

# %%
print("heelo".islower())
# Out:
# True

# %%
print("HHBNJNK".isupper())
# Out:
# True

# %%
print("  ".isspace())
# Out:
# True

# %%
print("Hhccd Hscsdcs".istitle())
# Out:
# True

# %%
print("*".join(["this","is","name"]))
# Out:
# this*is*name

# %%
print("heyhdt".ljust(3,"&"))
# Out:
# heyhdt

# %%
print("GYHBHN".lower())
print("cdsbcj".upper())
# Out:
# gyhbhn
# CDSBCJ

# %%
print("    hii     ".lstrip())
# Out:
# hii

# %%
print(str.maketrans("Sdff","dfs "))
# Out:
# {83: 100, 100: 102, 102: 32}

# %%
print("this is python class".rpartition(" "))
# Out:
# ('this is python', ' ', 'class')

# %%
print("this is python class".replace("c","m"))
# Out:
# this is python mlass

# %%
print("hiih".rfind("o"))
# Out:
# -1

# %%
print("hiih".rindex("i"))
print("HHJsbuc".swapcase())
# Out:
# 2
# hhjSBUC

# %%
table = str.maketrans("abc", "xyz")
"bbb".translate(table)
# Out:
# 'yyy'

# %%
print("22432".zfill(40))
# Out:
# 0000000000000000000000000000000000022432
