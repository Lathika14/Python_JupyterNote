# %% [markdown]
# ## Function

# %%
print("Hello world")
# Out:
# Hello world

# %%
def msg():
    print("Hello world")

msg()
# Out:
# Hello world

# %%
a="python"
len(a)
# Out:
# 6

# %%
def add():
    a=10
    b=20
    return a+b

add()
# Out:
# 30

# %%
def sub(a,b):
    print(a-b)

sub(10,70)
# Out:
# -60

# %%
def data(name,age,sub):
    print(f"Name : {name}, Age : {age}, Subject : {sub}")

data(age=23,name="lathia,",sub="etl")
# Out:
# Name : lathia,, Age : 23, Subject : etl

# %%
a=20
print("This is age : ",a)
# Out:
# This is age :  20

# %%
name=str(input("enter the name : "))
print(name)
# Out:
# enter the name :  345
# 345

# %%
age=int(input("Enter the age :"))
# Out:
# Enter the age : sdfgsdvdxv
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 age=int(input("Enter the age :"))
#
# ValueError: invalid literal for int() with base 10: 'sdfgsdvdxv'

# %%
num=int(input("enter num : "))

for i in range(num):
    print(i)
# Out:
# enter num :  3
# 0
# 1
# 2

# %%
def d(name, msg="welcome"):
    print(f"Name : {name}, {msg}")
d("lathika")
# Out:
# Name : lathika, welcome

# %%
def t(*g):
    print(g)
t("hii","hello",243)
# Out:
# ('hii', 'hello', 243)

# %%
x=20 #global 

def g():
    x=10 # local
    return x

g()
print(x)
# Out:
# 20

# %%
count =0

def c():
    global count
    count+=1

print(c())
c()
print(c())
c()

count
# Out:
# None
# None
# 4

# %%
def x():
    msg="hi"
    def y():
        nonlocal msg
        msg="hello"

    y()
    print(msg)

x()
# Out:
# hello

# %%
add= lambda a,b:a+b
print(add(2,4))
# Out:
# 6

# %%
a=10
b=80

c=a
a=b
b=c
print(a,b)
# Out:
# 80 10

# %%
a,b=b,a
print(a,b)
# Out:
# 10 80

# %%
x=90
y=60

x,y=y,x
print(x,y)
# Out:
# 60 90

# %%
def fact(n):
    if n==0:
        return 1

    else:
        return n*fact(n-1)

print(fact(1))
# Out:
# 1

# %%
import keyword as kd

# %%
a=kd.kwlist
a
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(a)
# Out:
# 35

# %%
kd.iskeyword
# Out:
# <function frozenset.__contains__>

# %%
import fact as f
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 import fact as f
#
# ModuleNotFoundError: No module named 'fact'

# %%
import pandas as pd

# %%
pd.

# %%
import datetime as d

# %%
d.datetime(12-09-2026)
# Out:
#   Cell In[8], line 1
#     d.datetime(12-09-2026)
#                   ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
d.now()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 d.now()
#
# AttributeError: module 'datetime' has no attribute 'now'

# %%
import math as m

# %%
m.pow(2,7)
# Out:
# 128.0

# %%
m.sqrt(3)
# Out:
# 1.7320508075688772

# %%
from datetime import datetime as dt

# %%
dt.now()
# Out:
# datetime.datetime(2026, 9, 4, 17, 31, 3, 780785)
