# %%
# %%load_ext sql
# Out:
# UsageError: Cell magic `%%load_ext` not found (But line magic `%load_ext` exists, did you mean that instead?).

# %%
mysql+mysqlconnector://root:12345@localhost/
# Out:
#   Cell In[3], line 1
#     mysql+mysqlconnector://root:12345@localhost/
#                         ^
# SyntaxError: invalid syntax
