# %% [markdown]
# + list
# + set
# + tuple
# + dict

# %% [markdown]
# ## List
#
# + [] stored
# + ordered
# + diff data type
# + duplicate value allowed
# + mutable
# + indexing
# + slicbale

# %%
a=[]
type(a)
# Out:
# list

# %%
a=[1,2,3,4,5,2,3,8]
print(a)
# Out:
# [1, 2, 3, 4, 5, 2, 3, 8]

# %%
a=[1,"hii","hello",2.3,True]
a
# Out:
# [1, 'hii', 'hello', 2.3, True]

# %%
a=[1,1,2,3,3,4]
a
# Out:
# [1, 1, 2, 3, 3, 4]

# %%
a[0]
# Out:
# 1

# %%
a[1]=2

# %%
a
# Out:
# [1, 2, 2, 3, 3, 4]

# %%
a[1:6]
# Out:
# [2, 2, 3, 3, 4]

# %%
a[0:2]
# Out:
# [1, 2]

# %%
a[0:3:2]
# Out:
# [1, 2]

# %%
a[0:6:3]
# Out:
# [1, 3]

# %%
a=[1,2,3,4,5,6,7,8]
a
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
a[1:7]
# Out:
# [2, 3, 4, 5, 6, 7]

# %%
a[::2]
# Out:
# [1, 3, 5, 7]

# %%
a[:7]
# Out:
# [1, 2, 3, 4, 5, 6, 7]

# %%
a[1::]
# Out:
# [2, 3, 4, 5, 6, 7, 8]

# %%
a[::-1]
# Out:
# [8, 7, 6, 5, 4, 3, 2, 1]

# %%
a.append(10)

# %%
a
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 10]

# %%
a.clear()

# %%
a
# Out:
# []

# %%
a=[1,2,3,4,5,6,7,8]
a
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
b=a.copy()

# %%
b
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
b.count(1)
# Out:
# 1

# %%
b.append(1)

# %%
b
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 1]

# %%
b.count(1)
# Out:
# 2

# %%
b.extend(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 b.extend(1)
#
# TypeError: 'int' object is not iterable

# %%
n=["heeloo"]
n.extend()
n
# Out:
# ['heeloo', 'h']

# %%
b.index(2)
# Out:
# 1

# %%
b.insert(0,11)

# %%
b
# Out:
# [11, 1, 2, 3, 4, 5, 6, 7, 8, 1, 1, 2, 3, 4, 5, 6, 7, 8]

# %%
b.extend(n)

# %%
b
# Out:
# [11, 1, 2, 3, 4, 5, 6, 7, 8, 1, 1, 2, 3, 4, 5, 6, 7, 8, 'heeloo', 'h']

# %%
b.pop(1)
# Out:
# 1

# %%
b
# Out:
# [11, 2, 3, 4, 5, 6, 7, 8, 1, 1, 2, 3, 4, 5, 6, 7, 8, 'heeloo', 'h']

# %%
b.remove(2)

# %%
b
# Out:
# [11, 3, 4, 5, 6, 7, 8, 1, 1, 2, 3, 4, 5, 6, 7, 8, 'heeloo', 'h']

# %%
b.reverse()

# %%
b
# Out:
# ['h', 'heeloo', 8, 7, 6, 5, 4, 3, 2, 1, 1, 8, 7, 6, 5, 4, 3, 11]

# %%
b.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 b.sort()
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
a.sort()

# %%
a
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
c=[22,4,3,11,66,4,8]
c.sort()
c
# Out:
# [3, 4, 4, 8, 11, 22, 66]

# %% [markdown]
# ## Tuple
#
# + ()
# + ordered
# + diff data type
# + duplicate value allowed
# + indixing
# + slicable
# + immutable

# %%
a=()
type(a)
# Out:
# tuple

# %%
a=(1,2,3,2,1,55)
a
# Out:
# (1, 2, 3, 2, 1, 55)

# %%
a=(1,"hii",True,3,3)
a
# Out:
# (1, 'hii', True, 3, 3)

# %%
a=(1,1,22,22,3,4,66,3)
a
# Out:
# (1, 1, 22, 22, 3, 4, 66, 3)

# %%
a[0]
# Out:
# 1

# %%
a[3]
# Out:
# 22

# %%
a[1:6:2]
# Out:
# (1, 22, 4)

# %%
a[0]=2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 a[0]=2
#
# TypeError: 'tuple' object does not support item assignment

# %%
a.count(22)
# Out:
# 2

# %%
a.index(22)
# Out:
# 2

# %%
a.index(66)
# Out:
# 6

# %%
a.index(9)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 a.index(9)
#
# ValueError: tuple.index(x): x not in tuple

# %%
a=2,3
a
# Out:
# (2, 3)

# %%
x,y=a

# %%
x
# Out:
# 2

# %%
y
# Out:
# 3

# %%
a,b,*c=(1,2,3,4,5,6,7,8)

# %%
print(a,b,c)
# Out:
# 1 2 [3, 4, 5, 6, 7, 8]

# %%
a=10
b=20
print(a,b)
# Out:
# 10 20

# %%
a,b=b,a

# %%
print(a,b)
# Out:
# 20 10

# %%
from collections import namedtuple

# %%
p=namedtuple("student",["a","b"])
p1=p(1,2)
p1.a,p1.b
p1[0],p1[1]

p1.replace(a=10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[95], line 6
#       2 p1=p(1,2)
#       3 p1.a,p1.b
#       4 p1[0],p1[1]
#       5
# ----> 6 p1.replace(a=10)
#
# AttributeError: 'student' object has no attribute 'replace'

# %%
data=(1,"value")

print(hash(data))
# Out:
# 2475187373059348183

# %%
data1={data: "detail" }
data1
data1[1,"value"]
# Out:
# 'detail'

# %%
data=(1,["hii","hello"])

# %%
hash(data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 hash(data)
#
# TypeError: unhashable type: 'list'

# %%
d=(1,"hi")
hash(d)
# Out:
# 9100024095776863721

# %%
for i in range(5):
    i=i**2
    print(i)
i
# Out:
# 0
# 1
# 4
# 9
# 16
# 16

# %%
d=tuple(i**2 for i in range(5))
d
# Out:
# (0, 1, 4, 9, 16)

# %% [markdown]
# ## Set
#
# + unordered
# + diff data types support
# + duplicate not allowed
# + mutable
# + not indexing

# %%
s=set()
type(s)
s={}
s
# Out:
# {}

# %%
s={1,2,3,4}
type(s)
s
# Out:
# {1, 2, 3, 4}

# %%
s={23,54,22,785,453,123,897,453,13,9087,707}
s
# Out:
# {13, 22, 23, 54, 123, 453, 707, 785, 897, 9087}

# %%
s={1,"hii",True,34.2}

# %%
s
# Out:
# {1, 34.2, 'hii'}

# %%
s={1,1,2,2,33,22,33,56,65,56,77}
s
type(s)
# Out:
# set

# %%
s=set()
type(s)
# Out:
# set

# %%
s
# Out:
# {1, 2, 22, 33, 56, 65, 77}

# %%
s.add(245)

# %%
s
# Out:
# {1, 2, 22, 33, 56, 65, 77, 245}

# %%
s.clear()

# %%
s
# Out:
# set()

# %%
data = s.copy()

# %%
data
# Out:
# {1, 2, 22, 33, 56, 65, 77}

# %%
data.pop()
# Out:
# 65

# %%
data
# Out:
# {1, 2, 22, 33, 56, 77}

# %%
data.pop(77)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 data.pop(77)
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
data.remove(77)

# %%
data
# Out:
# {1, 2, 22, 33, 56}

# %%
d=data.union(s)

# %%
d
# Out:
# {1, 2, 22, 33, 56, 65, 77}

# %%
a={1,2,3,4,5}
b={6,7,8,9,80,5}
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9, 80}

# %%
b.union(a)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9, 80}

# %%
a.discard(4)

# %%
a
# Out:
# {1, 2, 3, 5}

# %%
a.update()

# %%
a
# Out:
# {1, 2, 3, 5}

# %%
c=a.intersection(b)

# %%
a
# Out:
# {1, 2, 3, 5}

# %%
b
# Out:
# {6, 7, 8, 9, 80}

# %%
c
# Out:
# set()

# %%
a={1,2,3,4,5}
b={6,7,8,9,80,5}

# %%
a.intersection(b)
# Out:
# {5}

# %%
a.difference(b)
# Out:
# {1, 2, 3, 4}

# %%
b.difference(a)
# Out:
# {6, 7, 8, 9, 80}

# %%
a.symmetric_difference(b)
# Out:
# {1, 2, 3, 4, 6, 7, 8, 9, 80}

# %%
a.intersection_update(b)

# %%
a
# Out:
# {5}

# %%
a
# Out:
# {5}

# %%
a
# Out:
# {5}

# %%
a.difference_update(b)

# %%
a
# Out:
# set()

# %%
a
# Out:
# set()

# %%
a
# Out:
# {1, 2, 3, 4, 5}

# %%
a.issubset(b)
# Out:
# False

# %%
a={1,2,3,4}
b={6,7,8,9,80}

# %%
a.issuperset(b)
# Out:
# False

# %%
b.issuperset(a)
# Out:
# False

# %%
x={1,2,3,5,4,6,7,88}
y={1,2,3,4,5,6,7,88,99}

x.issuperset(y)
y.issuperset(x)
# x.issubset(y)
# y.issubset(x)
x.isdisjoint(y)
# Out:
# False

# %%
a.isdisjoint(b)
# Out:
# True

# %% [markdown]
# ## dict
#
# + {}
# + ordered
# + mutable
# + diff data type allowed

# %%
d={}
type(d)
# Out:
# dict

# %%
d=dict()
type(d)
# Out:
# dict

# %%
d={"name" : "lathika","age" : 45}
d
# Out:
# {'name': 'lathika', 'age': 45}

# %%
d
# Out:
# {'name': 'hi', 'age': 45}

# %%
dict.fromkeys(d)
# Out:
# {'name': None, 'age': None}

# %%
d
# Out:
# {'name': 'lathika', 'age': 45}

# %%
d.get("name")
# Out:
# 'lathika'

# %%
d.get("age")
# Out:
# 45

# %%
d.get(45)

# %%
d
# Out:
# {'name': 'lathika', 'age': 45}

# %%
d.items()
# Out:
# dict_items([('name', 'lathika'), ('age', 45)])

# %%
d.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
d.pop("age")
# Out:
# 45

# %%
d
# Out:
# {'name': 'lathika'}

# %%
d.popitem()
# Out:
# ('name', 'lathika')

# %%
d
# Out:
# {}

# %%
d={"name" : "lathika","age" : 45}

# %%
d.popitem()
# Out:
# ('name', 'lathika')

# %%
d
# Out:
# {}

# %%
d.setdefault("a",[]).append("all")

# %%
d
# Out:
# {'a': ['all', 'all']}

# %%
d.update()

# %%
d
# Out:
# {'a': ['all', 'all']}

# %%
d
# Out:
# {'a': ['all', 'all']}

# %%
d.values()
# Out:
# dict_values([['all', 'all']])

# %%
d.keys()
# Out:
# dict_keys(['a'])

# %%
d.values()
# Out:
# dict_values([['all', 'all']])

# %%
c=d.copy()

# %%
c
# Out:
# {'a': 44}

# %%
c.setdefault("a",[]).append(33)

# %%
c
# Out:
# {'a': ['all', 'all', 33]}

# %%
d
# Out:
# {'a': ['all', 'all', 33]}

# %%
d
# Out:
# {'a': ['all', 'all', 33]}

# %%
c.clear()

# %%
c
# Out:
# {}

# %%
d
# Out:
# {'a': ['all', 'all', 33]}

# %%
for key in d:
    print(key)
# Out:
# a

# %%
for values in c.values():
    print(values)
# Out:
# 44

# %%
d["a"]=44

# %%
d
# Out:
# {'a': 44}

# %%
d["a"]
# Out:
# 44

# %%
c["name"]="lathika"

# %%
c
# Out:
# {'a': 44, 'name': 'lathika'}

# %%
d
# Out:
# {'a': 44, 'age': 33}

# %%
d["age"]=33

# %%
d
# Out:
# {'a': 44, 'age': 33}

# %%
c
# Out:
# {'a': 44, 'name': 'lathika'}

# %%
for key, value in c.items():
    print(key,value)
# Out:
# a 44
# name lathika

# %%
m=dict(d,**c)

# %%
m
# Out:
# {'a': 44, 'age': 33, 'name': 'lathika'}

# %%
m={**d,**c}
m
# Out:
# {'a': 44, 'age': 33, 'name': 'lathika'}

# %%
a
# Out:
# {1, 2, 3, 4}

# %%
m
# Out:
# {'a': 44, 'age': 33, 'name': 'lathika'}

# %%
from collections import defaultdict

counter = defaultdict(int)
for ch in 'mississippi':
    counter[ch] += 1

# %%
counter
# Out:
# defaultdict(int, {'m': 1, 'i': 4, 's': 4, 'p': 2})
