# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
data = [22,33,44,55,66]
data
# Out:
# [22, 33, 44, 55, 66]

# %%
data = pd.Series(data)

# %%
data
# Out:
# 0    22
# 1    33
# 2    44
# 3    55
# 4    66
# dtype: int64

# %%
data[0]
# Out:
# np.int64(22)

# %%
data.loc[0]
# Out:
# np.int64(22)

# %%
data = pd.Series([10,20,30,40,32],index=["a","b","c","d","e"])

# %%
data
# Out:
# a    10
# b    20
# c    30
# d    40
# e    32
# dtype: int64

# %%
data.loc["d"]
# Out:
# np.int64(40)

# %%
data.loc["c"]
# Out:
# np.int64(30)

# %%
data.iloc[0]
# Out:
# np.int64(10)

# %%
print(data[(data>=30) & (data<=35)])
# Out:
# c    30
# e    32
# dtype: int64

# %% [markdown]
# ### DataFrame

# %%
d={
    'Name' : ['Vinoth','lathika','babu'],
    'age' : [22,23,24],
    'subject' : ['DA','ETL','genai']
}

# %%
d
# Out:
# {'Name': ['Vinoth', 'lathika', 'babu'],
#  'age': [22, 23, 24],
#  'subject': ['DA', 'ETL', 'genai']}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#       Name  age subject
# 0   Vinoth   22      DA
# 1  lathika   23     ETL
# 2     babu   24   genai

# %%
df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df.loc[0]
# Out:
# Name       Vinoth
# age            22
# subject        DA
# Name: 0, dtype: object

# %%
df.loc[2]
# Out:
# Name        babu
# age           24
# subject    genai
# Name: 2, dtype: object

# %%
print(df[df['age']>=23])
# Out:
#       Name  age subject
# 1  lathika   23     ETL
# 2     babu   24   genai

# %%
d1=pd.DataFrame({'Name':"devi",'age':23,'subject':'QA'},index=[3])

# %%
d1
# Out:
#    Name  age subject
# 3  devi   23      QA

# %%
df
# Out:
#       Name  age subject
# 0   Vinoth   22      DA
# 1  lathika   23     ETL
# 2     babu   24   genai

# %%
df=pd.concat([df,d1])

# %%
df
# Out:
#       Name  age subject
# 0   Vinoth   22      DA
# 1  lathika   23     ETL
# 2     babu   24   genai
# 3     devi   23      QA

# %%
df[(df['subject']=='QA') | (df['age']>=25)]
# Out:
#    Name  age subject
# 3  devi   23      QA

# %%
df[~ (df['subject']=='QA') | (df['age']>=25)]
# Out:
#       Name  age subject
# 0   Vinoth   22      DA
# 1  lathika   23     ETL
# 2     babu   24   genai

# %% [markdown]
# ### Readfiles

# %%
file = pd.read_csv('C:\\Users\\Admin\\OneDrive\\Documents\\CourseNotes\\employee_data_cleaning_practice_200_rows.csv')

# %%
file
# Out:
#     Employee_ID Employee_Name   Age  Gender         Department        City  \
# 0             1   Sneha Kumar  38.0  Female            finance   Bangalore
# 1             2   Arun Sharma  34.0       F            finance     Chennai
# 2             3    Anitha Rao  17.0    male         Operations     chennai
# 3             4  Sneha Sharma  45.0    Male          Marketing     Chennai
# 4             5     Sneha Das  26.0       F         Operations     Chennai
# ..          ...           ...   ...     ...                ...         ...
# 195         196     Kavya Rao  51.0    Male          Marketing       Delhi
# 196         197   Nisha Kumar  32.0       M   Human Resources      chennai
# 197         198     Arun Iyer   0.0     NaN   Human Resources         Pune
# 198         199  Suresh Reddy  28.0       M          Marketing  BANGALORE
# 199         200   Gokul Reddy  32.0  female            finance     chennai
#
# ...

# %%
print(file.to_string())
# Out:
#     Employee_ID    Employee_Name   Age  Gender         Department        City                         Email Employment_Type     Salary Joining_Date  Performance_Score  Attendance_Percentage
# 0             1      Sneha Kumar  38.0  Female            finance   Bangalore        sneha.kumar1@gmail.com       Part time      53000   03-07-2020                NaN                   75.0
# 1             2      Arun Sharma  34.0       F            finance     Chennai      arun.sharma2@company.com        contract      53000   01-09-2023                6.0                    NaN
# 2             3       Anitha Rao  17.0    male         Operations     chennai         anitha.rao3@gmail.com       Part-Time      58000   27-01-2018                4.0                  100.0
# 3             4     Sneha Sharma  45.0    Male          Marketing     Chennai       sneha.sharma4@yahoo.com        contract      33000   10-01-2022                0.0                   -5.0
# ...

# %%
file.columns
# Out:
# Index(['Employee_ID', 'Employee_Name', 'Age', 'Gender', 'Department', 'City',
#        'Email', 'Employment_Type', 'Salary', 'Joining_Date',
#        'Performance_Score', 'Attendance_Percentage'],
#       dtype='str')

# %%
file.head()
# Out:
#   Employee_ID Employee_Name   Age  Gender  Department       City  \
# 0           1   Sneha Kumar  38.0  Female     finance  Bangalore
# 1           2   Arun Sharma  34.0       F     finance    Chennai
# 2           3    Anitha Rao  17.0    male  Operations    chennai
# 3           4  Sneha Sharma  45.0    Male   Marketing    Chennai
# 4           5     Sneha Das  26.0       F  Operations    Chennai
#
#                       Email Employment_Type  Salary Joining_Date  \
# 0    sneha.kumar1@gmail.com       Part time   53000   03-07-2020
# 1  arun.sharma2@company.com        contract   53000   01-09-2023
# 2     anitha.rao3@gmail.com       Part-Time   58000   27-01-2018
# 3   sneha.sharma4@yahoo.com        contract   33000   10-01-2022
# 4    sneha.das5@company.com        contract  103000   15-04-2021
#
#    Performance_Score  Attendance_Percentage
# 0                NaN                   75.0
# 1                6.0                    NaN
# 2                4.0                  100.0
# ...

# %%
file.tail()
# Out:
#     Employee_ID Employee_Name   Age  Gender         Department        City  \
# 195         196     Kavya Rao  51.0    Male          Marketing       Delhi
# 196         197   Nisha Kumar  32.0       M   Human Resources      chennai
# 197         198     Arun Iyer   0.0     NaN   Human Resources         Pune
# 198         199  Suresh Reddy  28.0       M          Marketing  BANGALORE
# 199         200   Gokul Reddy  32.0  female            finance     chennai
#
#                            Email Employment_Type  Salary Joining_Date  \
# 195       kavya.rao196@yahoo.com             NaN  118000   27-03-2020
# 196     nisha.kumar197@gmail.com        contract   83000   22-12-2019
# 197       arun.iyer198@yahoo.com       Part-Time  113000   16-03-2019
# 198  suresh.reddy199@company.com       Full-Time   68000   28-10-2019
# 199     gokul.reddy200@yahoo.com       Full-Time  113000   01-03-2025
#
#      Performance_Score  Attendance_Percentage
# 195                2.0                   90.0
# ...

# %%
file.head(100)
# Out:
#    Employee_ID Employee_Name   Age  Gender  Department       City  \
# 0            1   Sneha Kumar  38.0  Female     finance  Bangalore
# 1            2   Arun Sharma  34.0       F     finance    Chennai
# 2            3    Anitha Rao  17.0    male  Operations    chennai
# 3            4  Sneha Sharma  45.0    Male   Marketing    Chennai
# 4            5     Sneha Das  26.0       F  Operations    Chennai
# ..         ...           ...   ...     ...         ...        ...
# 95          96    Manoj Iyer  55.0    male       SALES      Delhi
# 96          97    Manoj Iyer  33.0  female          it     Mumbai
# 97          98      Arun Das  38.0     NaN       SALES    Chennai
# 98          99  Swetha Singh  35.0  Female     Finance       Pune
# 99         100   Manoj Kumar  17.0  female   Marketing  Bangalore
#
#                          Email Employment_Type  Salary Joining_Date  \
# 0       sneha.kumar1@gmail.com       Part time   53000   03-07-2020
# ...

# %%
file.tail(10)
# Out:
#     Employee_ID Employee_Name   Age  Gender         Department        City  \
# 190         191   Vijay Reddy  38.0       F          Marketing        Pune
# 191         192   Deepa Singh   NaN   Male               SALES   Bangalore
# 192         193   Meena Kumar  39.0     NaN          Marketing  BANGALORE
# 193         194   Suresh Nair  38.0       F              Sales     Chennai
# 194         195  Anitha Kumar  27.0       M                 HR  BANGALORE
# 195         196     Kavya Rao  51.0    Male          Marketing       Delhi
# 196         197   Nisha Kumar  32.0       M   Human Resources      chennai
# 197         198     Arun Iyer   0.0     NaN   Human Resources         Pune
# 198         199  Suresh Reddy  28.0       M          Marketing  BANGALORE
# 199         200   Gokul Reddy  32.0  female            finance     chennai
#
#                            Email Employment_Type  Salary Joining_Date  \
# 190     vijay.reddy191@gmail.com        contract  103000   07-05-2021
# ...

# %%
file[['Employee_ID','Employee_Name','Age']].head(10)
# Out:
#   Employee_ID  Employee_Name   Age
# 0           1    Sneha Kumar  38.0
# 1           2    Arun Sharma  34.0
# 2           3     Anitha Rao  17.0
# 3           4   Sneha Sharma  45.0
# 4           5      Sneha Das  26.0
# 5           6    Anitha Iyer  26.0
# 6           7     Vijay Iyer  25.0
# 7           8    Nisha Reddy  41.0
# 8           9      Vijay Rao  46.0
# 9          10  Suresh Joseph  48.0

# %%
file.describe()
# Out:
#               Age  Performance_Score  Attendance_Percentage
# count  182.000000         180.000000             180.000000
# mean    38.137363           3.150000              77.333333
# std     12.475294           1.962569              35.138990
# min      0.000000           0.000000              -5.000000
# 25%     29.000000           2.000000              80.000000
# 50%     40.000000           3.500000              90.000000
# 75%     48.000000           5.000000             100.000000
# max     65.000000           6.000000             105.000000

# %%
file.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Employee_ID            200 non-null    str
#  1   Employee_Name          200 non-null    str
#  2   Age                    182 non-null    float64
#  3   Gender                 177 non-null    str
#  4   Department             197 non-null    str
#  5   City                   200 non-null    str
#  6   Email                  200 non-null    str
#  7   Employment_Type        164 non-null    str
#  8   Salary                 193 non-null    str
#  9   Joining_Date           196 non-null    str
#  10  Performance_Score      180 non-null    float64
#  11  Attendance_Percentage  180 non-null    float64
# dtypes: float64(3), str(9)
# memory usage: 18.9 KB

# %%
file.head(20)
# Out:
#    Employee_ID  Employee_Name   Age  Gender         Department        City  \
# 0            1    Sneha Kumar  38.0  Female            finance   Bangalore
# 1            2    Arun Sharma  34.0       F            finance     Chennai
# 2            3     Anitha Rao  17.0    male         Operations     chennai
# 3            4   Sneha Sharma  45.0    Male          Marketing     Chennai
# 4            5      Sneha Das  26.0       F         Operations     Chennai
# 5            6    Anitha Iyer  26.0  female   Human Resources         Pune
# 6            7     Vijay Iyer  25.0       M              Sales    Hyderbad
# 7            8    Nisha Reddy  41.0    male                 it       Delhi
# 8            9      Vijay Rao  46.0       F            Finance        Pune
# 9           10  Suresh Joseph  48.0     NaN            Finance      Mumbai
# 10          11  Karthik Patel  48.0     NaN              SALES     chennai
# ...

# %%
file.loc[10:20]
# Out:
#    Employee_ID  Employee_Name   Age  Gender Department        City  \
# 10          11  Karthik Patel  48.0     NaN      SALES     chennai
# 11          12    Arun Sharma  55.0   Male   Marketing   Bangalore
# 12          13    Suresh Nair  32.0       F    finance        Pune
# 13          14     Nisha Nair  21.0  female         HR     Chennai
# 14          15    Priya Reddy   0.0       M         HR  BANGALORE
# 15          16     Divya Iyer  54.0    male      Sales    Hyderbad
# 16          17      hari rao   28.0       F         IT       Delhi
# 17          18    Rahul Kumar  35.0       F    finance   Bangalore
# 18          19    Nisha Patel   NaN       F         it  BANGALORE
# 19          20      Pooja Das  47.0   Male          IT   Bangalore
# 20          21   Anitha Reddy  33.0    male    Finance     chennai
#
#                         Email Employment_Type  Salary Joining_Date  \
# 10  karthik.patel11@yahoo.com       Part time  113000   18-09-2018
# ...

# %%
file.iloc[15:30:5]
# Out:
#    Employee_ID  Employee_Name   Age Gender Department      City  \
# 15          16     Divya Iyer  54.0   male      Sales  Hyderbad
# 20          21   Anitha Reddy  33.0   male    Finance   chennai
# 25          26  Swetha Sharma  36.0   Male      SALES    Mumbai
#
#                           Email Employment_Type  Salary Joining_Date  \
# 15       divya.iyer16@gmail.com       full time  113000   30-09-2022
# 20     anitha.reddy21@gmail.com       full time  103000   12-01-2023
# 25  swetha.sharma26@company.com       Part time   78000   07-05-2019
#
#     Performance_Score  Attendance_Percentage
# 15                3.5                  105.0
# 20                4.0                   80.0
# 25                2.0                    NaN

# %%
file[["Employee_ID","Employee_Name","Age"]].loc[(file['Age']==30)]
# Out:
#     Employee_ID Employee_Name   Age
# 44           45  Anitha Reddy  30.0
# 49           50   Rahul Patel  30.0
# 139         140  Rahul Joseph  30.0

# %%
excel = pd.read_excel('C:\\Users\\Admin\\OneDrive\\Documents\\CourseNotes\\Data_Analyst_Practice_Dataset_excel.xlsx',sheet_name='')

# %%
pip install openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
excel
# Out:
#     OrderID        Date CustomerID ProductID EmpID        City State  Qty  \
# 0     O0001  2026-02-07       C205      P004  E026  Coimbatore    TN    1
# 1     O0002  2026-03-15       C172      P002  E017   Hyderabad    TS    7
# 2     O0003  2026-03-15       C042      P004  E096        Pune    MH    2
# 3     O0004  2026-05-28       C125      P002  E085   Bangalore    KA    9
# 4     O0005  2026-05-08       C160      P005  E053     Chennai    TN    9
# ..      ...         ...        ...       ...   ...         ...   ...  ...
# 495   O0496  2026-01-12       C201      P004  E058     Chennai    TN    3
# 496   O0497  2026-01-30       C248      P005  E013        Pune    MH    6
# 497   O0498  2026-01-17       C199      P004  E058   Hyderabad    TS    6
# 498   O0499  2026-03-15       C076      P005  E028     Chennai    TN    8
# 499   O0500  2026-06-15       C218      P002  E082   Hyderabad    TS    1
#
#      UnitPrice  Discount   Sales
# 0        15000         0   15000
# ...

# %%
excel[excel['Sales']>=1000]
# Out:
#     OrderID        Date CustomerID ProductID EmpID        City State  Qty  \
# 0     O0001  2026-02-07       C205      P004  E026  Coimbatore    TN    1
# 1     O0002  2026-03-15       C172      P002  E017   Hyderabad    TS    7
# 2     O0003  2026-03-15       C042      P004  E096        Pune    MH    2
# 3     O0004  2026-05-28       C125      P002  E085   Bangalore    KA    9
# 4     O0005  2026-05-08       C160      P005  E053     Chennai    TN    9
# ..      ...         ...        ...       ...   ...         ...   ...  ...
# 494   O0495  2026-02-05       C137      P005  E015   Bangalore    KA    1
# 495   O0496  2026-01-12       C201      P004  E058     Chennai    TN    3
# 496   O0497  2026-01-30       C248      P005  E013        Pune    MH    6
# 497   O0498  2026-01-17       C199      P004  E058   Hyderabad    TS    6
# 498   O0499  2026-03-15       C076      P005  E028     Chennai    TN    8
#
#      UnitPrice  Discount   Sales
# 0        15000         0   15000
# ...

# %%
excel[~(excel['Sales']>=1000) & (excel['State']=='TN')]
# Out:
#     OrderID        Date CustomerID ProductID EmpID     City State  Qty  \
# 125   O0126  2026-03-13       C043      P002  E026  Chennai    TN    1
#
#      UnitPrice  Discount  Sales
# 125        700        10    630

# %%
excel[excel['State'].isin(['TN','TS','KA'])]
# Out:
#     OrderID        Date CustomerID ProductID EmpID        City State  Qty  \
# 0     O0001  2026-02-07       C205      P004  E026  Coimbatore    TN    1
# 1     O0002  2026-03-15       C172      P002  E017   Hyderabad    TS    7
# 3     O0004  2026-05-28       C125      P002  E085   Bangalore    KA    9
# 4     O0005  2026-05-08       C160      P005  E053     Chennai    TN    9
# 6     O0007  2026-02-23       C065      P002  E048     Chennai    TN    2
# ..      ...         ...        ...       ...   ...         ...   ...  ...
# 494   O0495  2026-02-05       C137      P005  E015   Bangalore    KA    1
# 495   O0496  2026-01-12       C201      P004  E058     Chennai    TN    3
# 497   O0498  2026-01-17       C199      P004  E058   Hyderabad    TS    6
# 498   O0499  2026-03-15       C076      P005  E028     Chennai    TN    8
# 499   O0500  2026-06-15       C218      P002  E082   Hyderabad    TS    1
#
#      UnitPrice  Discount   Sales
# 0        15000         0   15000
# ...

# %%
print(excel.to_string())
# Out:
#     OrderID        Date CustomerID ProductID EmpID        City State  Qty  UnitPrice  Discount   Sales
# 0     O0001  2026-02-07       C205      P004  E026  Coimbatore    TN    1      15000         0   15000
# 1     O0002  2026-03-15       C172      P002  E017   Hyderabad    TS    7        700         0    4900
# 2     O0003  2026-03-15       C042      P004  E096        Pune    MH    2      15000        10   27000
# 3     O0004  2026-05-28       C125      P002  E085   Bangalore    KA    9        700        10    5670
# 4     O0005  2026-05-08       C160      P005  E053     Chennai    TN    9      18000         5  153900
# 5     O0006  2026-01-23       C177      P003  E065        Pune    MH    3       1200        15    3060
# 6     O0007  2026-02-23       C065      P002  E048     Chennai    TN    2        700        10    1260
# 7     O0008  2026-01-16       C032      P001  E030   Hyderabad    TS    8      55000        10  396000
# ...

# %%
excel[(excel['State']=='TN') & (excel['Discount']>5)].str.
# Out:
#     OrderID        Date CustomerID ProductID EmpID        City State  Qty  \
# 6     O0007  2026-02-23       C065      P002  E048     Chennai    TN    2
# 20    O0021  2026-06-28       C167      P003  E073  Coimbatore    TN   10
# 32    O0033  2026-04-01       C019      P005  E024  Coimbatore    TN    3
# 34    O0035  2026-02-24       C268      P003  E023  Coimbatore    TN   10
# 41    O0042  2026-04-26       C251      P005  E008     Chennai    TN   10
# ..      ...         ...        ...       ...   ...         ...   ...  ...
# 468   O0469  2026-02-15       C061      P002  E011     Chennai    TN    6
# 473   O0474  2026-05-09       C282      P005  E084  Coimbatore    TN    2
# 476   O0477  2026-02-27       C200      P004  E035  Coimbatore    TN    6
# 486   O0487  2026-06-03       C293      P001  E089  Coimbatore    TN   10
# 495   O0496  2026-01-12       C201      P004  E058     Chennai    TN    3
#
#      UnitPrice  Discount   Sales
# 6          700        10    1260
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[116], line 1
# ----> 1 file[['Employee_ID','Employee_Name']].str.title()
#
# File ~\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6202             and name not in self._accessors
#    6203             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6204         ):
#    6205             return self[name]
# -> 6206         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
file.sort_values('Age').head(50)
# Out:
#     Employee_ID   Employee_Name   Age  Gender         Department        City  \
# 14           15     Priya Reddy   0.0       M                 HR  BANGALORE
# 76           77    Meena Joseph   0.0   Male           Marketing  BANGALORE
# 128         129       Gokul Das   0.0    male                 it    Chennai
# 173         174     Rahul Kumar   0.0    Male                 it     Chennai
# 197         198       Arun Iyer   0.0     NaN   Human Resources         Pune
# 114         115    Karthik Iyer  17.0    male              SALES     chennai
# 99          100     Manoj Kumar  17.0  female          Marketing   Bangalore
# 2             3      Anitha Rao  17.0    male         Operations     chennai
# 32           33      Kavya Nair  21.0    Male            finance   Hyderabad
# 39           40       Priya Das  21.0   Male          Operations      Mumbai
# 13           14      Nisha Nair  21.0  female                 HR     Chennai
# ...

# %%
file.sort_values(['Salary','Age'],ascending=False).head(20)
# Out:
#     Employee_ID Employee_Name   Age  Gender         Department        City  \
# 24           25  Priya Joseph  51.0  Female            finance     Chennai
# 112         113  Gokul Sharma  49.0    male            finance     Chennai
# 111         112   Priya Patel  47.0     NaN   Human Resources    Bangalore
# 12           13   Suresh Nair  32.0       F            finance        Pune
# 39           40     Priya Das  21.0   Male          Operations      Mumbai
# 141         142   Divya Reddy  42.0  Female            Finance   Hyderabad
# 183         184   Priya Patel  42.0       M              SALES   Hyderabad
# 144         145   Nisha Reddy  40.0     NaN   Human Resources      Chennai
# 179         180   Priya Kumar  39.0    Male          Marketing  BANGALORE
# 164         165   Sneha Kumar  32.0    male                 HR    Hyderbad
# 133         134   Karthik Rao  25.0    Male          Marketing        Pune
# ...
