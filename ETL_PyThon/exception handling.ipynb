# %% [markdown]
# ## Exception Handling

# %%
print("hii")
print("hello")
printt("hey") # compile time error
# Out:
# hii
# hello
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 print("hii")
#       2 print("hello")
# ----> 3 printt("hey")
#
# NameError: name 'printt' is not defined

# %%
#run time error

a=int(input())
b=int(input())
# Out:
#  2
#  d
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 4
#       1 #run time error
#       2
#       3 a=int(input())
# ----> 4 b=int(input())
#
# ValueError: invalid literal for int() with base 10: 'd'

# %%
#run time error

a=int(input())
b=int(input())
c=a/b
c
# Out:
#  2
#  d
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 4
#       1 #run time error
#       2
#       3 a=int(input())
# ----> 4 b=int(input())
#       5 c=a/b
#       6 c
#
# ValueError: invalid literal for int() with base 10: 'd'

# %%
a=10
b=30
print(a+a)
# Out:
# 20

# %%
a=int(input())
b=int(input())
c=input()
# d=c/a
print(type(c))
# Out:
#  2
#  2
#  2
# <class 'str'>

# %%
try:
    a=int(input())
    b=int(input())
    c=input()
except TypeError as e:
    print("somthing wrong",e)
except ValueError as e:
    print("this is value error",e)
else:
    print("finished")
finally:
    print("finish")
# Out:
#  2
#  3
#  e
# finished
# finish

# %%
try:
    a=int(input())
    b=int(input())
    c=input()
    d=c/a
except Exception as e:
    print("something error",e)
finally :
    print("done")
# Out:
#  2
#  2
#  2
# something error unsupported operand type(s) for /: 'str' and 'int'
# done

# %%
d={"a":1}
d
# Out:
# {'a': 1}

# %%
d["b"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 d["b"]
#
# KeyError: 'b'

# %%
impor tracback
# Out:
#   Cell In[33], line 1
#     impor tracback
#           ^
# SyntaxError: invalid syntax

# %%
try :
    print(10/0)
except Exception as e:
    print("error",e)
    traceback.print_exc()
# Out:
# error division by zero
# Traceback (most recent call last):
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_4260\3583915167.py", line 2, in <module>
#     print(10/0)
#           ~~^~
# ZeroDivisionError: division by zero

# %%
def set_age(age):
    if age < 0:
        raise ValueError('Age cannot be negative')
    return age
 
set_age(5)
# Out:
# 5

# %%
def f():
    try:
        return 10
    finally :
        return 20
f()
# Out:
# 20

# %%
di={"a":1,"b":2}
di
d={}
di["a"]
# Out:
# 1

# %%
for key in d.keys(): #LBYL
    print(key)

# %%
try:
    k=di["s"]
    print(k)
except KeyError as e:
    print("error")
# Out:
# error

# %%
def calculate_average(numbers):
    assert len(numbers) > 0, 'List must not be empty'
    return sum(numbers) / len(numbers)
 
calculate_average([])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[49], line 5
#       1 def calculate_average(numbers):
#       2     assert len(numbers) > 0, 'List must not be empty'
#       3     return sum(numbers) / len(numbers)
#       4
# ----> 5 calculate_average([])
#
# Cell In[49], line 2, in calculate_average(numbers)
#       1 def calculate_average(numbers):
# ----> 2     assert len(numbers) > 0, 'List must not be empty'
#       3     return sum(numbers) / len(numbers)
#
# AssertionError: List must not be empty

# %%
import logging
logging.basicConfig(level=logging.ERROR)
logger = logging.getLogger(__name__)

try:
    k=di["s"]
    print(k)
except KeyError as e:
    logger.exception("error")
    logger.error('Division failed', exc_info=True)
# Out:
# ERROR:__main__:error
# Traceback (most recent call last):
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_4260\2419278861.py", line 6, in <module>
#     k=di["s"]
#       ~~^^^^^
# KeyError: 's'
# ERROR:__main__:Division failed
# Traceback (most recent call last):
#   File "C:\Users\Admin\AppData\Local\Temp\ipykernel_4260\2419278861.py", line 6, in <module>
#     k=di["s"]
#       ~~^^^^^
# KeyError: 's'
